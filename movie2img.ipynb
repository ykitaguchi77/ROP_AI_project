# %% [markdown]
# # **MOVIE2IMG**
#
# MP4ファイルをjpgファイルに分割

# %%
1+1
# Out:
# 'Python 3.10.6' でセルを実行するには、 ipykernel パッケージが必要です。
#
# 次のコマンドを実行して、'ipykernel' を Python 環境にインストールします。
#
# コマンド: '/Users/kitaguchi/.pyenv/versions/3.10.6/bin/python -m pip install ipykernel -U --force-reinstall'
