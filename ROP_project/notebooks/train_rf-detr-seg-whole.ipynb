# %% [markdown]
# # **Train RF-DETR-N-whole (Nano)**
#
# RF-DETRは、Roboflowが開発したリアルタイムの物体検出モデルです。
# このノートブックでは、RF-DETR-N（Nano）モデルをカスタムデータセットでトレーニングします。
#
# 参考: https://github.com/roboflow/rf-detr
#
# ---
#
# ## ⚠️ 使用前の注意
#
# **データの前処理は `train_yolo-seg.ipynb` で行ってください。**
#
# このノートブックは、`train_yolo-seg.ipynb` で準備されたYOLO形式のデータ（`data/train/`）を
# COCO形式に変換してRF-DETRでトレーニングします。
#
# ### ワークフロー
# 1. **`train_yolo-seg.ipynb`** でデータの前処理・分割を実行
#    - 画像の円形マスク適用
#    - ラベルファイル（Fundus, Disc, Macula）のコピー
#    - train/valid分割
# 2. **このノートブック** でYOLO→COCO変換 & RF-DETR-Nトレーニングを実行
#    - **Lensアノテーションを自動生成**（画像の内接円）
#    - 既存クラスのIDを+1シフト（Fundus:0→1, Disc:1→2, Macula:2→3）
#    - 最終的に4クラス（Lens, Fundus, Disc, Macula）で学習
#
# ### クラス定義
# | Class ID | Class Name | 説明 |
# |----------|------------|------|
# | 0 | Lens | 画像の内接円（自動生成） |
# | 1 | Fundus | 眼底（網膜） |
# | 2 | Disc | 視神経乳頭 |
# | 3 | Macula | 黄斑 |
#
# ※ `data/train/` 内のYOLOデータおよび `data/train_coco/` 内のCOCOデータは、毎回のトレーニングで自動更新されます。

# %%
# CUDAが使えるかどうかを確認
import torch

cuda_available = torch.cuda.is_available()

if cuda_available:
    print(f"CUDA is available! GPU: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available.")
# Out:
# CUDA is available! GPU: Quadro RTX 5000

# %%
# 環境の確認
import torch
import sys
print(f"Python version: {sys.version}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"PyTorch CUDA version: {torch.version.cuda}")
# Out:
# Python version: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# PyTorch CUDA version: 12.1

# %%
# RF-DETRのインストール
# 初回のみ実行してください
# !pip install rfdetr

# %% [markdown]
# ## **RF-DETR データセット構造**
#
# RF-DETRはCOCO形式のデータセットを使用します。
#
# ```
# dataset/
# ├── train/
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── _annotations.coco.json
# ├── valid/
# │   ├── image1.jpg
# │   └── _annotations.coco.json
# ```
#
# 既存のYOLO形式データをCOCO形式に変換する必要があります。

# %% [markdown]
# ## **Step 1: データの準備**
#
# train_yolo-seg.ipynbと同様のデータ前処理を行います。

# %%
# データディレクトリの設定
import os

# 既存のYOLO形式データのパス
YOLO_DATA_DIR = r'C:\Users\ykita\ROP_AI_project\ROP_project\data\train'

# RF-DETR用のCOCO形式データの出力パス
COCO_DATA_DIR = r'C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco'

# クラス定義（Lensを追加: 画像の内接円として自動生成）
# Lens: 0, Fundus: 1, Disc: 2, Macula: 3
CLASSES = ['Lens', 'Fundus', 'Disc', 'Macula']
NUM_CLASSES = len(CLASSES)

print(f"YOLO Data Directory: {YOLO_DATA_DIR}")
print(f"COCO Data Directory: {COCO_DATA_DIR}")
print(f"Number of classes: {NUM_CLASSES}")
print(f"Classes: {CLASSES}")
# Out:
# YOLO Data Directory: C:\Users\ykita\ROP_AI_project\ROP_project\data\train
# COCO Data Directory: C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco
# Number of classes: 4
# Classes: ['Lens', 'Fundus', 'Disc', 'Macula']

# %%
# Lens円形ポリゴン生成関数
# 画像の内接円（中心: 画像中央、半径: 短辺の半分）をCOCO形式で生成

import math

def generate_lens_annotation(width, height, annotation_id, image_id, num_points=32):
    """
    画像の内接円としてLensアノテーションを生成
    
    Args:
        width: 画像の幅
        height: 画像の高さ
        annotation_id: アノテーションID
        image_id: 画像ID
        num_points: 円を近似するポリゴンの頂点数（デフォルト32）
    
    Returns:
        dict: COCO形式のアノテーション
    """
    # 円の中心と半径を計算
    center_x = width / 2
    center_y = height / 2
    radius = min(width, height) / 2
    
    # 円をポリゴンで近似（num_points個の頂点）
    segmentation = []
    for i in range(num_points):
        angle = 2 * math.pi * i / num_points
        x = center_x + radius * math.cos(angle)
        y = center_y + radius * math.sin(angle)
        segmentation.extend([x, y])
    
    # バウンディングボックスを計算 [x_min, y_min, width, height]
    x_min = center_x - radius
    y_min = center_y - radius
    bbox_width = radius * 2
    bbox_height = radius * 2
    
    # 円の面積
    area = math.pi * radius * radius
    
    # COCO形式のアノテーション
    annotation = {
        "id": annotation_id,
        "image_id": image_id,
        "category_id": 0,  # Lens = class 0
        "bbox": [x_min, y_min, bbox_width, bbox_height],
        "area": area,
        "segmentation": [segmentation],
        "iscrowd": 0
    }
    
    return annotation

# テスト
test_annotation = generate_lens_annotation(640, 480, 0, 0)
print("=== Lens Annotation Example ===")
print(f"BBox: {test_annotation['bbox']}")
print(f"Area: {test_annotation['area']:.2f}")
print(f"Segmentation points: {len(test_annotation['segmentation'][0]) // 2}")
# Out:
# === Lens Annotation Example ===
# BBox: [80.0, 0.0, 480.0, 480.0]
# Area: 180955.74
# Segmentation points: 32

# %%
# YOLO形式（セグメンテーション）からCOCO形式への変換
# 
# 変更点:
# - 既存のclass_idを+1シフト（Fundus:0→1, Disc:1→2, Macula:2→3）
# - 各画像にLens（class_id=0）を自動追加（画像の内接円）
#
# YOLO Segmentation形式:
#   class_id x1 y1 x2 y2 x3 y3 ... (normalized coordinates)
#
# COCO Detection形式:
#   annotations.json with bounding boxes

import json
import os
from PIL import Image
from tqdm import tqdm
import shutil

def yolo_seg_to_coco(yolo_images_dir, yolo_labels_dir, output_dir, classes, split_name):
    """
    YOLO Segmentation形式からCOCO Detection形式に変換
    
    変更点:
    - 既存アノテーションのclass_idを+1シフト（Lensをclass 0として追加するため）
    - 各画像にLens（class_id=0）アノテーションを自動生成
    
    Args:
        yolo_images_dir: YOLO形式の画像ディレクトリ
        yolo_labels_dir: YOLO形式のラベルディレクトリ
        output_dir: 出力ディレクトリ
        classes: クラスのリスト（Lens, Fundus, Disc, Macula）
        split_name: 'train' or 'valid'
    """
    # 出力ディレクトリの作成
    output_images_dir = os.path.join(output_dir, split_name)
    os.makedirs(output_images_dir, exist_ok=True)
    
    # COCO形式のアノテーション構造
    coco_annotations = {
        "images": [],
        "annotations": [],
        "categories": []
    }
    
    # カテゴリの追加（Lens, Fundus, Disc, Macula）
    for idx, class_name in enumerate(classes):
        coco_annotations["categories"].append({
            "id": idx,
            "name": class_name,
            "supercategory": "object"
        })
    
    annotation_id = 0
    image_id = 0
    
    # 統計情報（クラス別カウント）
    class_counts = {class_name: 0 for class_name in classes}
    
    # 画像ファイルのリストを取得
    image_files = [f for f in os.listdir(yolo_images_dir) 
                   if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    
    print(f"Processing {len(image_files)} images for {split_name}...")
    
    for img_file in tqdm(image_files, desc=f"Converting {split_name}"):
        img_path = os.path.join(yolo_images_dir, img_file)
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(yolo_labels_dir, label_file)
        
        # 画像サイズの取得
        try:
            with Image.open(img_path) as img:
                width, height = img.size
        except Exception as e:
            print(f"Error reading image {img_path}: {e}")
            continue
        
        # 画像情報の追加
        coco_annotations["images"].append({
            "id": image_id,
            "file_name": img_file,
            "width": width,
            "height": height
        })
        
        # 画像をコピー
        dst_img_path = os.path.join(output_images_dir, img_file)
        if not os.path.exists(dst_img_path):
            shutil.copy(img_path, dst_img_path)
        
        # === Lensアノテーションを自動追加（class_id=0）===
        lens_annotation = generate_lens_annotation(width, height, annotation_id, image_id)
        coco_annotations["annotations"].append(lens_annotation)
        annotation_id += 1
        class_counts['Lens'] += 1
        
        # === 既存のラベルファイルの処理（class_idを+1シフト）===
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                lines = f.readlines()
            
            for line in lines:
                parts = line.strip().split()
                if len(parts) < 5:  # 少なくともclass_id + 2点（4座標）が必要
                    continue
                
                # 元のclass_idを取得し、+1シフト
                original_class_id = int(parts[0])
                shifted_class_id = original_class_id + 1  # Fundus:0→1, Disc:1→2, Macula:2→3
                
                # クラス名を取得してカウント
                if shifted_class_id < len(classes):
                    class_counts[classes[shifted_class_id]] += 1
                
                # セグメンテーション座標を取得
                coords = list(map(float, parts[1:]))
                
                # ペアになっていない場合はスキップ
                if len(coords) % 2 != 0:
                    continue
                
                # 正規化された座標をピクセル座標に変換
                x_coords = [coords[i] * width for i in range(0, len(coords), 2)]
                y_coords = [coords[i] * height for i in range(1, len(coords), 2)]
                
                # バウンディングボックスを計算
                x_min = min(x_coords)
                y_min = min(y_coords)
                x_max = max(x_coords)
                y_max = max(y_coords)
                
                bbox_width = x_max - x_min
                bbox_height = y_max - y_min
                
                # セグメンテーション（ポリゴン）の作成
                segmentation = []
                for i in range(0, len(coords), 2):
                    segmentation.append(coords[i] * width)
                    segmentation.append(coords[i + 1] * height)
                
                # アノテーションの追加（シフトされたclass_idを使用）
                coco_annotations["annotations"].append({
                    "id": annotation_id,
                    "image_id": image_id,
                    "category_id": shifted_class_id,  # +1シフト済み
                    "bbox": [x_min, y_min, bbox_width, bbox_height],
                    "area": bbox_width * bbox_height,
                    "segmentation": [segmentation],
                    "iscrowd": 0
                })
                annotation_id += 1
        
        image_id += 1
    
    # アノテーションファイルの保存
    annotations_path = os.path.join(output_images_dir, '_annotations.coco.json')
    with open(annotations_path, 'w') as f:
        json.dump(coco_annotations, f, indent=2)
    
    # 結果表示
    print(f"Saved {split_name} annotations to {annotations_path}")
    print(f"  - Images: {len(coco_annotations['images'])}")
    print(f"  - Total Annotations: {len(coco_annotations['annotations'])}")
    print(f"  - Per Class:")
    for class_name in classes:
        print(f"      {class_name}: {class_counts[class_name]}")
    
    return coco_annotations

# %%
# YOLO形式からCOCO形式に変換を実行

# 出力ディレクトリのクリア（必要に応じて）
if os.path.exists(COCO_DATA_DIR):
    print(f"Removing existing directory: {COCO_DATA_DIR}")
    shutil.rmtree(COCO_DATA_DIR)
os.makedirs(COCO_DATA_DIR, exist_ok=True)

# Train データの変換
train_yolo_images = os.path.join(YOLO_DATA_DIR, 'images', 'train')
train_yolo_labels = os.path.join(YOLO_DATA_DIR, 'labels', 'train')

print("\n=== Converting Train Data ===")
train_coco = yolo_seg_to_coco(
    yolo_images_dir=train_yolo_images,
    yolo_labels_dir=train_yolo_labels,
    output_dir=COCO_DATA_DIR,
    classes=CLASSES,
    split_name='train'
)

# Valid データの変換
valid_yolo_images = os.path.join(YOLO_DATA_DIR, 'images', 'valid')
valid_yolo_labels = os.path.join(YOLO_DATA_DIR, 'labels', 'valid')

print("\n=== Converting Valid Data ===")
valid_coco = yolo_seg_to_coco(
    yolo_images_dir=valid_yolo_images,
    yolo_labels_dir=valid_yolo_labels,
    output_dir=COCO_DATA_DIR,
    classes=CLASSES,
    split_name='valid'
)

# Testディレクトリを作成（RF-DETRが必要とするため、validデータをコピー）
print("\n=== Creating Test Directory (copy from valid) ===")
test_dir = os.path.join(COCO_DATA_DIR, 'test')
valid_dir = os.path.join(COCO_DATA_DIR, 'valid')
os.makedirs(test_dir, exist_ok=True)

# validディレクトリの内容をtestにコピー
for item in os.listdir(valid_dir):
    src = os.path.join(valid_dir, item)
    dst = os.path.join(test_dir, item)
    if os.path.isfile(src):
        shutil.copy(src, dst)
print(f"Copied valid data to test directory: {test_dir}")

print("\n=== Conversion Complete ===")
# Out:
# Removing existing directory: C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco
#
# === Converting Train Data ===
# Processing 16479 images for train...
# Converting train: 100%|██████████| 16479/16479 [01:18<00:00, 210.01it/s]
# Saved train annotations to C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco\train\_annotations.coco.json
#   - Images: 16479
#   - Total Annotations: 33302
#   - Per Class:
#       Lens: 16479
#       Fundus: 9875
#       Disc: 4701
#       Macula: 2247
#
# === Converting Valid Data ===
# Processing 4023 images for valid...
# Converting valid: 100%|██████████| 4023/4023 [00:11<00:00, 359.87it/s]
# Saved valid annotations to C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco\valid\_annotations.coco.json
#   - Images: 4023
#   - Total Annotations: 8881
#   - Per Class:
#       Lens: 4023
#       Fundus: 2364
#       Disc: 1329
#       Macula: 1165
#
# === Creating Test Directory (copy from valid) ===
# Copied valid data to test directory: C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco\test
#
# === Conversion Complete ===

# %%
# 変換結果の確認

import os

def count_files_in_directory(directory):
    """指定されたディレクトリ内のファイル数をカウントする"""
    if not os.path.exists(directory):
        return 0
    return len([f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))])

train_dir = os.path.join(COCO_DATA_DIR, 'train')
valid_dir = os.path.join(COCO_DATA_DIR, 'valid')

print("=== COCO Format Data Summary ===")
print(f"Train directory: {train_dir}")
print(f"  Files: {count_files_in_directory(train_dir)}")
print(f"Valid directory: {valid_dir}")
print(f"  Files: {count_files_in_directory(valid_dir)}")
# Out:
# === COCO Format Data Summary ===
# Train directory: C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco\train
#   Files: 16480
# Valid directory: C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco\valid
#   Files: 4024

# %% [markdown]
# ## **Step 2: RF-DETR-N トレーニング**

# %%
# RF-DETRのインポートとモデルの初期化
from rfdetr import RFDETRNano

# RF-DETR-Nano モデルの作成
model = RFDETRNano()

print("RF-DETR-Nano model loaded successfully!")
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# RF-DETR-Nano model loaded successfully!

# %%
# トレーニングパラメータの設定

# トレーニング設定
EPOCHS = 100
BATCH_SIZE = 4  # メモリ不足の場合は2に下げる
LEARNING_RATE = 1e-4
LEARNING_RATE_ENCODER = 1.5e-4
WEIGHT_DECAY = 1e-4
RESOLUTION = 448  # 56と32の公倍数（56×8=448, 32×14=448）

# Early Stopping設定
EARLY_STOPPING = True
EARLY_STOPPING_PATIENCE = 20

# 出力ディレクトリ（4クラスモデル用）
OUTPUT_DIR = r'C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr_4class'

print("=== Training Configuration ===")
print(f"Epochs: {EPOCHS}")
print(f"Batch Size: {BATCH_SIZE}")
print(f"Learning Rate: {LEARNING_RATE}")
print(f"Resolution: {RESOLUTION}")
print(f"Output Directory: {OUTPUT_DIR}")
# Out:
# === Training Configuration ===
# Epochs: 100
# Batch Size: 4
# Learning Rate: 0.0001
# Resolution: 448
# Output Directory: C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr_4class

# %%
# RF-DETR-N トレーニングの実行

model.train(
    dataset_dir=COCO_DATA_DIR,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    grad_accum_steps=4,
    lr=LEARNING_RATE,
    lr_encoder=LEARNING_RATE_ENCODER,
    weight_decay=WEIGHT_DECAY,
    resolution=RESOLUTION,
    use_ema=True,
    checkpoint_interval=1,  # 毎エポックでチェックポイント保存（best更新時にbest.ptも保存）
    tensorboard=True,
    early_stopping=EARLY_STOPPING,
    early_stopping_patience=EARLY_STOPPING_PATIENCE,
    early_stopping_min_delta=0.001,
    early_stopping_use_ema=True,
    device="cuda",
    output_dir=OUTPUT_DIR
)
# Out:
# Unable to initialize TensorBoard. Logging is turned off for this session.  Run 'pip install tensorboard' to enable logging.
# Not using distributed mode
# git:
#   sha: c9e5f12edab392a6d9c582998bd9ac2b138293fc, status: has uncommited changes, branch: master
#
# Namespace(num_classes=4, grad_accum_steps=4, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=100, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-nano.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=2, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\data\\train_coco', square_resize_div_64=True, output_dir='C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\runs\\rfdetr_4class', dont_save_weights=False, checkpoint_interval=1, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=448, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=True, early_stopping_patience=20, early_stopping_min_delta=0.001, early_stopping_use_ema=True, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=24, mask_downsample_ratio=4, tensorboard=True, wandb=False, project=None, run=None, class_names=['Lens', 'Fundus', 'Disc', 'Macula'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 30154272
# [608]
# loading annotations into memory...
# Done (t=1.38s)
# creating index...
# index created!
# [608]
# loading annotations into memory...
# Done (t=0.34s)
# creating index...
# index created!
# [608]
# loading annotations into memory...
# Done (t=0.80s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 1029
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
# Epoch: [0]  [   0/1029]  eta: 7:25:52  lr: 0.000100  class_error: 78.85  loss: 6.5959 (6.5959)  loss_ce: 1.1630 (1.1630)  loss_bbox: 0.5261 (0.5261)  loss_giou: 0.4949 (0.4949)  loss_ce_0: 1.2069 (1.2069)  loss_bbox_0: 0.4518 (0.4518)  loss_giou_0: 0.4668 (0.4668)  loss_ce_enc: 1.0946 (1.0946)  loss_bbox_enc: 0.5936 (0.5936)  loss_giou_enc: 0.5980 (0.5980)  loss_ce_unscaled: 1.1630 (1.1630)  class_error_unscaled: 78.8462 (78.8462)  loss_bbox_unscaled: 0.1052 (0.1052)  loss_giou_unscaled: 0.2475 (0.2475)  cardinality_error_unscaled: 3183.2500 (3183.2500)  loss_ce_0_unscaled: 1.2069 (1.2069)  loss_bbox_0_unscaled: 0.0904 (0.0904)  loss_giou_0_unscaled: 0.2334 (0.2334)  cardinality_error_0_unscaled: 3318.7500 (3318.7500)  loss_ce_enc_unscaled: 1.0946 (1.0946)  loss_bbox_enc_unscaled: 0.1187 (0.1187)  loss_giou_enc_unscaled: 0.2990 (0.2990)  cardinality_error_enc_unscaled: 3394.2500 (3394.2500)  time: 25.9984  data: 21.7313  max mem: 3131
# Epoch: [0]  [  10/1029]  eta: 1:18:44  lr: 0.000100  class_error: 30.07  loss: 5.8756 (5.8517)  loss_ce: 1.2866 (1.3076)  loss_bbox: 0.3392 (0.3229)  loss_giou: 0.3034 (0.2778)  loss_ce_0: 1.2811 (1.3037)  loss_bbox_0: 0.3864 (0.3389)  loss_giou_0: 0.2954 (0.2945)  loss_ce_enc: 1.1719 (1.1842)  loss_bbox_enc: 0.5071 (0.4600)  loss_giou_enc: 0.3644 (0.3623)  loss_ce_unscaled: 1.2866 (1.3076)  class_error_unscaled: 52.5641 (54.2206)  loss_bbox_unscaled: 0.0678 (0.0646)  loss_giou_unscaled: 0.1517 (0.1389)  cardinality_error_unscaled: 3863.2500 (3693.8409)  loss_ce_0_unscaled: 1.2811 (1.3037)  loss_bbox_0_unscaled: 0.0773 (0.0678)  loss_giou_0_unscaled: 0.1477 (0.1472)  cardinality_error_0_unscaled: 3616.7500 (3606.4318)  loss_ce_enc_unscaled: 1.1719 (1.1842)  loss_bbox_enc_unscaled: 0.1014 (0.0920)  loss_giou_enc_unscaled: 0.1822 (0.1811)  cardinality_error_enc_unscaled: 3885.2500 (3753.8182)  time: 4.6367  data: 1.9802  max mem: 4298
# Epoch: [0]  [  20/1029]  eta: 1:02:02  lr: 0.000100  class_error: 25.00  loss: 5.6940 (5.7315)  loss_ce: 1.2492 (1.2490)  loss_bbox: 0.2965 (0.3233)  loss_giou: 0.2673 (0.2688)  loss_ce_0: 1.2657 (1.2899)  loss_bbox_0: 0.2971 (0.3287)  loss_giou_0: 0.2740 (0.2777)  loss_ce_enc: 1.1719 (1.2089)  loss_bbox_enc: 0.4312 (0.4451)  loss_giou_enc: 0.3318 (0.3402)  loss_ce_unscaled: 1.2492 (1.2490)  class_error_unscaled: 23.6686 (34.4279)  loss_bbox_unscaled: 0.0593 (0.0647)  loss_giou_unscaled: 0.1336 (0.1344)  cardinality_error_unscaled: 3865.2500 (3771.4881)  loss_ce_0_unscaled: 1.2657 (1.2899)  loss_bbox_0_unscaled: 0.0594 (0.0657)  loss_giou_0_unscaled: 0.1370 (0.1388)  cardinality_error_0_unscaled: 3639.0000 (3635.6905)  loss_ce_enc_unscaled: 1.1719 (1.2089)  loss_bbox_enc_unscaled: 0.0862 (0.0890)  loss_giou_enc_unscaled: 0.1659 (0.1701)  cardinality_error_enc_unscaled: 3894.5000 (3820.0595)  time: 2.5742  data: 0.0068  max mem: 4650
# Epoch: [0]  [  30/1029]  eta: 0:55:06  lr: 0.000100  class_error: 10.77  loss: 5.2939 (5.5175)  loss_ce: 1.0021 (1.1405)  loss_bbox: 0.2965 (0.3157)  loss_giou: 0.2511 (0.2662)  loss_ce_0: 1.1923 (1.2429)  loss_bbox_0: 0.2783 (0.3204)  loss_giou_0: 0.2512 (0.2713)  loss_ce_enc: 1.1523 (1.1978)  loss_bbox_enc: 0.3848 (0.4300)  loss_giou_enc: 0.3318 (0.3328)  loss_ce_unscaled: 1.0021 (1.1405)  class_error_unscaled: 10.7692 (26.4360)  loss_bbox_unscaled: 0.0593 (0.0631)  loss_giou_unscaled: 0.1256 (0.1331)  cardinality_error_unscaled: 3807.5000 (3756.7258)  loss_ce_0_unscaled: 1.1923 (1.2429)  loss_bbox_0_unscaled: 0.0557 (0.0641)  loss_giou_0_unscaled: 0.1256 (0.1357)  cardinality_error_0_unscaled: 3574.5000 (3570.8468)  loss_ce_enc_unscaled: 1.1523 (1.1978)  loss_bbox_enc_unscaled: 0.0770 (0.0860)  loss_giou_enc_unscaled: 0.1659 (0.1664)  cardinality_error_enc_unscaled: 3882.2500 (3807.2258)  time: 2.5794  data: 0.0073  max mem: 4650
# Epoch: [0]  [  40/1029]  eta: 0:52:08  lr: 0.000100  class_error: 0.00  loss: 4.9948 (5.3337)  loss_ce: 0.8412 (1.0527)  loss_bbox: 0.3034 (0.3075)  loss_giou: 0.2288 (0.2589)  loss_ce_0: 1.1108 (1.2030)  loss_bbox_0: 0.2783 (0.3083)  loss_giou_0: 0.2320 (0.2633)  loss_ce_enc: 1.2096 (1.2094)  loss_bbox_enc: 0.3751 (0.4105)  loss_giou_enc: 0.2527 (0.3200)  loss_ce_unscaled: 0.8412 (1.0527)  class_error_unscaled: 9.2308 (22.5484)  loss_bbox_unscaled: 0.0607 (0.0615)  loss_giou_unscaled: 0.1144 (0.1295)  cardinality_error_unscaled: 3742.0000 (3746.3171)  loss_ce_0_unscaled: 1.1108 (1.2030)  loss_bbox_0_unscaled: 0.0557 (0.0617)  loss_giou_0_unscaled: 0.1160 (0.1316)  cardinality_error_0_unscaled: 3528.0000 (3560.8293)  loss_ce_enc_unscaled: 1.2096 (1.2094)  loss_bbox_enc_unscaled: 0.0750 (0.0821)  loss_giou_enc_unscaled: 0.1264 (0.1600)  cardinality_error_enc_unscaled: 3829.7500 (3813.3720)  time: 2.6098  data: 0.0064  max mem: 4650
# Epoch: [0]  [  50/1029]  eta: 0:49:13  lr: 0.000100  class_error: -0.00  loss: 4.7218 (5.2015)  loss_ce: 0.7600 (0.9852)  loss_bbox: 0.2947 (0.2998)  loss_giou: 0.1935 (0.2497)  loss_ce_0: 1.0971 (1.1775)  loss_bbox_0: 0.2702 (0.3026)  loss_giou_0: 0.1943 (0.2561)  loss_ce_enc: 1.2236 (1.2139)  loss_bbox_enc: 0.3519 (0.4065)  loss_giou_enc: 0.2305 (0.3101)  loss_ce_unscaled: 0.7600 (0.9852)  class_error_unscaled: 1.7094 (19.4727)  loss_bbox_unscaled: 0.0589 (0.0600)  loss_giou_unscaled: 0.0967 (0.1249)  cardinality_error_unscaled: 3794.7500 (3760.6225)  loss_ce_0_unscaled: 1.0971 (1.1775)  loss_bbox_0_unscaled: 0.0540 (0.0605)  loss_giou_0_unscaled: 0.0972 (0.1281)  cardinality_error_0_unscaled: 3811.5000 (3616.2843)  loss_ce_enc_unscaled: 1.2236 (1.2139)  loss_bbox_enc_unscaled: 0.0704 (0.0813)  loss_giou_enc_unscaled: 0.1152 (0.1551)  cardinality_error_enc_unscaled: 3869.5000 (3826.4902)  time: 2.5628  data: 0.0055  max mem: 4650
# Epoch: [0]  [  60/1029]  eta: 0:46:57  lr: 0.000100  class_error: -0.00  loss: 4.6009 (5.1235)  loss_ce: 0.6938 (0.9389)  loss_bbox: 0.2717 (0.2966)  loss_giou: 0.2159 (0.2493)  loss_ce_0: 1.0715 (1.1608)  loss_bbox_0: 0.2679 (0.2989)  loss_giou_0: 0.2003 (0.2581)  loss_ce_enc: 1.2006 (1.2009)  loss_bbox_enc: 0.3698 (0.4080)  loss_giou_enc: 0.2373 (0.3122)  loss_ce_unscaled: 0.6938 (0.9389)  class_error_unscaled: 0.7692 (17.3288)  loss_bbox_unscaled: 0.0543 (0.0593)  loss_giou_unscaled: 0.1079 (0.1246)  cardinality_error_unscaled: 3485.0000 (3669.6516)  loss_ce_0_unscaled: 1.0715 (1.1608)  loss_bbox_0_unscaled: 0.0536 (0.0598)  loss_giou_0_unscaled: 0.1002 (0.1290)  cardinality_error_0_unscaled: 3750.5000 (3623.0369)  loss_ce_enc_unscaled: 1.2006 (1.2009)  loss_bbox_enc_unscaled: 0.0740 (0.0816)  loss_giou_enc_unscaled: 0.1186 (0.1561)  cardinality_error_enc_unscaled: 3854.7500 (3825.7131)  time: 2.3841  data: 0.0043  max mem: 4650
# Epoch: [0]  [  70/1029]  eta: 0:45:35  lr: 0.000100  class_error: 0.00  loss: 4.5005 (5.0540)  loss_ce: 0.6789 (0.9022)  loss_bbox: 0.2588 (0.2940)  loss_giou: 0.2331 (0.2488)  loss_ce_0: 1.0005 (1.1405)  loss_bbox_0: 0.2507 (0.2970)  loss_giou_0: 0.2246 (0.2566)  loss_ce_enc: 1.1253 (1.1912)  loss_bbox_enc: 0.4072 (0.4117)  loss_giou_enc: 0.2808 (0.3122)  loss_ce_unscaled: 0.6789 (0.9022)  class_error_unscaled: 0.7692 (15.6002)  loss_bbox_unscaled: 0.0518 (0.0588)  loss_giou_unscaled: 0.1166 (0.1244)  cardinality_error_unscaled: 3128.7500 (3564.4014)  loss_ce_0_unscaled: 1.0005 (1.1405)  loss_bbox_0_unscaled: 0.0501 (0.0594)  loss_giou_0_unscaled: 0.1123 (0.1283)  cardinality_error_0_unscaled: 3544.2500 (3564.5246)  loss_ce_enc_unscaled: 1.1253 (1.1912)  loss_bbox_enc_unscaled: 0.0814 (0.0823)  loss_giou_enc_unscaled: 0.1404 (0.1561)  cardinality_error_enc_unscaled: 3802.2500 (3796.8099)  time: 2.4347  data: 0.0049  max mem: 4650
# Epoch: [0]  [  80/1029]  eta: 0:44:03  lr: 0.000100  class_error: 0.00  loss: 4.3526 (4.9458)  loss_ce: 0.6432 (0.8670)  loss_bbox: 0.2378 (0.2864)  loss_giou: 0.1909 (0.2380)  loss_ce_0: 0.9584 (1.1187)  loss_bbox_0: 0.2380 (0.2899)  loss_giou_0: 0.1767 (0.2449)  loss_ce_enc: 1.0572 (1.1799)  loss_bbox_enc: 0.4587 (0.4174)  loss_giou_enc: 0.2686 (0.3036)  loss_ce_unscaled: 0.6432 (0.8670)  class_error_unscaled: 0.0000 (13.9056)  loss_bbox_unscaled: 0.0476 (0.0573)  loss_giou_unscaled: 0.0955 (0.1190)  cardinality_error_unscaled: 3017.5000 (3496.2994)  loss_ce_0_unscaled: 0.9584 (1.1187)  loss_bbox_0_unscaled: 0.0476 (0.0580)  loss_giou_0_unscaled: 0.0884 (0.1224)  cardinality_error_0_unscaled: 3213.5000 (3506.8827)  loss_ce_enc_unscaled: 1.0572 (1.1799)  loss_bbox_enc_unscaled: 0.0917 (0.0835)  loss_giou_enc_unscaled: 0.1343 (0.1518)  cardinality_error_enc_unscaled: 3789.5000 (3789.3056)  time: 2.4118  data: 0.0056  max mem: 4650
# Epoch: [0]  [  90/1029]  eta: 0:42:36  lr: 0.000100  class_error: 0.00  loss: 4.2516 (4.8757)  loss_ce: 0.5892 (0.8345)  loss_bbox: 0.2236 (0.2871)  loss_giou: 0.1719 (0.2314)  loss_ce_0: 0.9267 (1.0988)  loss_bbox_0: 0.2320 (0.2867)  loss_giou_0: 0.1621 (0.2366)  loss_ce_enc: 1.0572 (1.1746)  loss_bbox_enc: 0.4651 (0.4268)  loss_giou_enc: 0.2523 (0.2991)  loss_ce_unscaled: 0.5892 (0.8345)  class_error_unscaled: 0.0000 (12.5090)  loss_bbox_unscaled: 0.0447 (0.0574)  loss_giou_unscaled: 0.0860 (0.1157)  cardinality_error_unscaled: 3145.0000 (3460.5824)  loss_ce_0_unscaled: 0.9267 (1.0988)  loss_bbox_0_unscaled: 0.0464 (0.0573)  loss_giou_0_unscaled: 0.0810 (0.1183)  cardinality_error_0_unscaled: 3376.0000 (3502.9918)  loss_ce_enc_unscaled: 1.0572 (1.1746)  loss_bbox_enc_unscaled: 0.0930 (0.0854)  loss_giou_enc_unscaled: 0.1261 (0.1496)  cardinality_error_enc_unscaled: 3834.5000 (3794.2225)  time: 2.2628  data: 0.0064  max mem: 4650
# Epoch: [0]  [ 100/1029]  eta: 0:41:45  lr: 0.000100  class_error: 0.96  loss: 4.2442 (4.8001)  loss_ce: 0.5274 (0.8043)  loss_bbox: 0.2273 (0.2877)  loss_giou: 0.1787 (0.2292)  loss_ce_0: 0.8784 (1.0728)  loss_bbox_0: 0.2281 (0.2836)  loss_giou_0: 0.1854 (0.2341)  loss_ce_enc: 1.0453 (1.1587)  loss_bbox_enc: 0.4622 (0.4297)  loss_giou_enc: 0.2608 (0.2999)  loss_ce_unscaled: 0.5274 (0.8043)  class_error_unscaled: 0.0000 (11.3720)  loss_bbox_unscaled: 0.0455 (0.0575)  loss_giou_unscaled: 0.0893 (0.1146)  cardinality_error_unscaled: 3135.0000 (3413.4158)  loss_ce_0_unscaled: 0.8784 (1.0728)  loss_bbox_0_unscaled: 0.0456 (0.0567)  loss_giou_0_unscaled: 0.0927 (0.1171)  cardinality_error_0_unscaled: 3457.7500 (3492.7178)  loss_ce_enc_unscaled: 1.0453 (1.1587)  loss_bbox_enc_unscaled: 0.0924 (0.0859)  loss_giou_enc_unscaled: 0.1304 (0.1500)  cardinality_error_enc_unscaled: 3833.2500 (3794.1411)  time: 2.3388  data: 0.0070  max mem: 4650
# Epoch: [0]  [ 110/1029]  eta: 0:40:56  lr: 0.000100  class_error: 2.88  loss: 3.6752 (4.7028)  loss_ce: 0.5432 (0.7794)  loss_bbox: 0.1913 (0.2800)  loss_giou: 0.1807 (0.2241)  loss_ce_0: 0.8125 (1.0486)  loss_bbox_0: 0.2124 (0.2770)  loss_giou_0: 0.1854 (0.2291)  loss_ce_enc: 0.9885 (1.1410)  loss_bbox_enc: 0.4075 (0.4273)  loss_giou_enc: 0.2559 (0.2962)  loss_ce_unscaled: 0.5432 (0.7794)  class_error_unscaled: 0.0000 (10.4621)  loss_bbox_unscaled: 0.0383 (0.0560)  loss_giou_unscaled: 0.0904 (0.1121)  cardinality_error_unscaled: 2838.5000 (3350.7432)  loss_ce_0_unscaled: 0.8125 (1.0486)  loss_bbox_0_unscaled: 0.0425 (0.0554)  loss_giou_0_unscaled: 0.0927 (0.1145)  cardinality_error_0_unscaled: 3340.0000 (3471.9932)  loss_ce_enc_unscaled: 0.9885 (1.1410)  loss_bbox_enc_unscaled: 0.0815 (0.0855)  loss_giou_enc_unscaled: 0.1280 (0.1481)  cardinality_error_enc_unscaled: 3801.2500 (3793.2230)  time: 2.4469  data: 0.0062  max mem: 4650
# Epoch: [0]  [ 120/1029]  eta: 0:40:12  lr: 0.000100  class_error: 2.20  loss: 3.6752 (4.6321)  loss_ce: 0.5054 (0.7543)  loss_bbox: 0.1913 (0.2783)  loss_giou: 0.1905 (0.2227)  loss_ce_0: 0.7806 (1.0238)  loss_bbox_0: 0.2160 (0.2765)  loss_giou_0: 0.1931 (0.2277)  loss_ce_enc: 0.9065 (1.1194)  loss_bbox_enc: 0.4075 (0.4328)  loss_giou_enc: 0.2532 (0.2967)  loss_ce_unscaled: 0.5054 (0.7543)  class_error_unscaled: 0.0000 (9.9628)  loss_bbox_unscaled: 0.0383 (0.0557)  loss_giou_unscaled: 0.0952 (0.1113)  cardinality_error_unscaled: 2913.7500 (3341.3017)  loss_ce_0_unscaled: 0.7806 (1.0238)  loss_bbox_0_unscaled: 0.0432 (0.0553)  loss_giou_0_unscaled: 0.0965 (0.1138)  cardinality_error_0_unscaled: 3423.7500 (3484.0682)  loss_ce_enc_unscaled: 0.9065 (1.1194)  loss_bbox_enc_unscaled: 0.0815 (0.0866)  loss_giou_enc_unscaled: 0.1266 (0.1484)  cardinality_error_enc_unscaled: 3801.2500 (3796.0310)  time: 2.4399  data: 0.0058  max mem: 4650
# Epoch: [0]  [ 130/1029]  eta: 0:39:23  lr: 0.000100  class_error: 6.15  loss: 3.8787 (4.5698)  loss_ce: 0.4637 (0.7310)  loss_bbox: 0.2640 (0.2786)  loss_giou: 0.2159 (0.2243)  loss_ce_0: 0.7083 (0.9984)  loss_bbox_0: 0.2684 (0.2771)  loss_giou_0: 0.2162 (0.2292)  loss_ce_enc: 0.8508 (1.0942)  loss_bbox_enc: 0.4804 (0.4383)  loss_giou_enc: 0.2881 (0.2988)  loss_ce_unscaled: 0.4637 (0.7310)  class_error_unscaled: 0.0000 (9.4750)  loss_bbox_unscaled: 0.0528 (0.0557)  loss_giou_unscaled: 0.1079 (0.1121)  cardinality_error_unscaled: 3400.7500 (3351.1794)  loss_ce_0_unscaled: 0.7083 (0.9984)  loss_bbox_0_unscaled: 0.0537 (0.0554)  loss_giou_0_unscaled: 0.1081 (0.1146)  cardinality_error_0_unscaled: 3724.5000 (3502.6813)  loss_ce_enc_unscaled: 0.8508 (1.0942)  loss_bbox_enc_unscaled: 0.0961 (0.0877)  loss_giou_enc_unscaled: 0.1440 (0.1494)  cardinality_error_enc_unscaled: 3851.7500 (3799.9809)  time: 2.3826  data: 0.0052  max mem: 4650
# Epoch: [0]  [ 140/1029]  eta: 0:38:41  lr: 0.000100  class_error: 0.00  loss: 3.8787 (4.5222)  loss_ce: 0.4985 (0.7175)  loss_bbox: 0.2286 (0.2751)  loss_giou: 0.2464 (0.2266)  loss_ce_0: 0.7111 (0.9813)  loss_bbox_0: 0.2647 (0.2748)  loss_giou_0: 0.2427 (0.2328)  loss_ce_enc: 0.7866 (1.0730)  loss_bbox_enc: 0.4445 (0.4381)  loss_giou_enc: 0.3194 (0.3030)  loss_ce_unscaled: 0.4985 (0.7175)  class_error_unscaled: 0.0000 (8.8909)  loss_bbox_unscaled: 0.0457 (0.0550)  loss_giou_unscaled: 0.1232 (0.1133)  cardinality_error_unscaled: 3185.0000 (3296.5567)  loss_ce_0_unscaled: 0.7111 (0.9813)  loss_bbox_0_unscaled: 0.0529 (0.0550)  loss_giou_0_unscaled: 0.1213 (0.1164)  cardinality_error_0_unscaled: 3413.5000 (3455.1312)  loss_ce_enc_unscaled: 0.7866 (1.0730)  loss_bbox_enc_unscaled: 0.0889 (0.0876)  loss_giou_enc_unscaled: 0.1597 (0.1515)  cardinality_error_enc_unscaled: 3748.2500 (3780.6064)  time: 2.3543  data: 0.0043  max mem: 4650
# Epoch: [0]  [ 150/1029]  eta: 0:38:06  lr: 0.000100  class_error: 0.00  loss: 3.7811 (4.4713)  loss_ce: 0.5036 (0.7045)  loss_bbox: 0.2286 (0.2738)  loss_giou: 0.2464 (0.2264)  loss_ce_0: 0.7325 (0.9669)  loss_bbox_0: 0.2347 (0.2721)  loss_giou_0: 0.2323 (0.2316)  loss_ce_enc: 0.7691 (1.0542)  loss_bbox_enc: 0.4290 (0.4384)  loss_giou_enc: 0.3194 (0.3034)  loss_ce_unscaled: 0.5036 (0.7045)  class_error_unscaled: 0.0000 (8.5551)  loss_bbox_unscaled: 0.0457 (0.0548)  loss_giou_unscaled: 0.1232 (0.1132)  cardinality_error_unscaled: 2626.0000 (3249.7748)  loss_ce_0_unscaled: 0.7325 (0.9669)  loss_bbox_0_unscaled: 0.0469 (0.0544)  loss_giou_0_unscaled: 0.1161 (0.1158)  cardinality_error_0_unscaled: 2857.5000 (3404.0662)  loss_ce_enc_unscaled: 0.7691 (1.0542)  loss_bbox_enc_unscaled: 0.0858 (0.0877)  loss_giou_enc_unscaled: 0.1597 (0.1517)  cardinality_error_enc_unscaled: 3556.5000 (3762.8328)  time: 2.4211  data: 0.0041  max mem: 4650
# Epoch: [0]  [ 160/1029]  eta: 0:37:39  lr: 0.000100  class_error: 0.00  loss: 3.4685 (4.4173)  loss_ce: 0.4609 (0.6883)  loss_bbox: 0.2253 (0.2710)  loss_giou: 0.2075 (0.2256)  loss_ce_0: 0.6750 (0.9459)  loss_bbox_0: 0.2248 (0.2717)  loss_giou_0: 0.2137 (0.2324)  loss_ce_enc: 0.6920 (1.0313)  loss_bbox_enc: 0.4667 (0.4445)  loss_giou_enc: 0.3124 (0.3067)  loss_ce_unscaled: 0.4609 (0.6883)  class_error_unscaled: 0.0000 (8.2243)  loss_bbox_unscaled: 0.0451 (0.0542)  loss_giou_unscaled: 0.1037 (0.1128)  cardinality_error_unscaled: 2969.7500 (3243.3571)  loss_ce_0_unscaled: 0.6750 (0.9459)  loss_bbox_0_unscaled: 0.0450 (0.0543)  loss_giou_0_unscaled: 0.1068 (0.1162)  cardinality_error_0_unscaled: 3039.5000 (3398.6646)  loss_ce_enc_unscaled: 0.6920 (1.0313)  loss_bbox_enc_unscaled: 0.0933 (0.0889)  loss_giou_enc_unscaled: 0.1562 (0.1533)  cardinality_error_enc_unscaled: 3703.7500 (3762.1087)  time: 2.5206  data: 0.0044  max mem: 4650
# Epoch: [0]  [ 170/1029]  eta: 0:36:48  lr: 0.000100  class_error: 0.00  loss: 3.4239 (4.3781)  loss_ce: 0.4571 (0.6758)  loss_bbox: 0.2553 (0.2710)  loss_giou: 0.1858 (0.2259)  loss_ce_0: 0.6693 (0.9302)  loss_bbox_0: 0.2470 (0.2715)  loss_giou_0: 0.1947 (0.2326)  loss_ce_enc: 0.6641 (1.0093)  loss_bbox_enc: 0.5690 (0.4528)  loss_giou_enc: 0.2851 (0.3091)  loss_ce_unscaled: 0.4571 (0.6758)  class_error_unscaled: 0.0000 (7.8794)  loss_bbox_unscaled: 0.0511 (0.0542)  loss_giou_unscaled: 0.0929 (0.1129)  cardinality_error_unscaled: 3025.7500 (3213.4898)  loss_ce_0_unscaled: 0.6693 (0.9302)  loss_bbox_0_unscaled: 0.0494 (0.0543)  loss_giou_0_unscaled: 0.0974 (0.1163)  cardinality_error_0_unscaled: 3073.7500 (3371.1798)  loss_ce_enc_unscaled: 0.6641 (1.0093)  loss_bbox_enc_unscaled: 0.1138 (0.0906)  loss_giou_enc_unscaled: 0.1426 (0.1545)  cardinality_error_enc_unscaled: 3703.7500 (3755.8070)  time: 2.3448  data: 0.0047  max mem: 4650
# Epoch: [0]  [ 180/1029]  eta: 0:36:02  lr: 0.000100  class_error: 4.81  loss: 3.8441 (4.3475)  loss_ce: 0.4808 (0.6649)  loss_bbox: 0.2687 (0.2735)  loss_giou: 0.2242 (0.2288)  loss_ce_0: 0.6260 (0.9122)  loss_bbox_0: 0.2654 (0.2741)  loss_giou_0: 0.2315 (0.2352)  loss_ce_enc: 0.6520 (0.9886)  loss_bbox_enc: 0.5223 (0.4576)  loss_giou_enc: 0.3141 (0.3126)  loss_ce_unscaled: 0.4808 (0.6649)  class_error_unscaled: 0.0000 (7.6091)  loss_bbox_unscaled: 0.0537 (0.0547)  loss_giou_unscaled: 0.1121 (0.1144)  cardinality_error_unscaled: 2504.2500 (3172.0746)  loss_ce_0_unscaled: 0.6260 (0.9122)  loss_bbox_0_unscaled: 0.0531 (0.0548)  loss_giou_0_unscaled: 0.1157 (0.1176)  cardinality_error_0_unscaled: 2619.2500 (3331.9088)  loss_ce_enc_unscaled: 0.6520 (0.9886)  loss_bbox_enc_unscaled: 0.1045 (0.0915)  loss_giou_enc_unscaled: 0.1571 (0.1563)  cardinality_error_enc_unscaled: 3612.2500 (3746.0000)  time: 2.1144  data: 0.0045  max mem: 4650
# Epoch: [0]  [ 190/1029]  eta: 0:35:24  lr: 0.000100  class_error: 0.00  loss: 3.6708 (4.3024)  loss_ce: 0.4755 (0.6549)  loss_bbox: 0.2687 (0.2720)  loss_giou: 0.2444 (0.2297)  loss_ce_0: 0.5858 (0.8965)  loss_bbox_0: 0.2844 (0.2734)  loss_giou_0: 0.2348 (0.2364)  loss_ce_enc: 0.6252 (0.9688)  loss_bbox_enc: 0.4466 (0.4567)  loss_giou_enc: 0.3269 (0.3139)  loss_ce_unscaled: 0.4755 (0.6549)  class_error_unscaled: 0.0000 (7.3278)  loss_bbox_unscaled: 0.0537 (0.0544)  loss_giou_unscaled: 0.1222 (0.1148)  cardinality_error_unscaled: 2256.5000 (3113.0366)  loss_ce_0_unscaled: 0.5858 (0.8965)  loss_bbox_0_unscaled: 0.0569 (0.0547)  loss_giou_0_unscaled: 0.1174 (0.1182)  cardinality_error_0_unscaled: 2397.0000 (3273.9856)  loss_ce_enc_unscaled: 0.6252 (0.9688)  loss_bbox_enc_unscaled: 0.0893 (0.0913)  loss_giou_enc_unscaled: 0.1635 (0.1570)  cardinality_error_enc_unscaled: 3496.7500 (3728.5929)  time: 2.1944  data: 0.0042  max mem: 4650
# Epoch: [0]  [ 200/1029]  eta: 0:35:02  lr: 0.000100  class_error: 0.00  loss: 3.3793 (4.2597)  loss_ce: 0.4680 (0.6469)  loss_bbox: 0.2415 (0.2710)  loss_giou: 0.2357 (0.2282)  loss_ce_0: 0.6468 (0.8847)  loss_bbox_0: 0.2582 (0.2727)  loss_giou_0: 0.2064 (0.2343)  loss_ce_enc: 0.6153 (0.9512)  loss_bbox_enc: 0.4285 (0.4581)  loss_giou_enc: 0.3252 (0.3127)  loss_ce_unscaled: 0.4680 (0.6469)  class_error_unscaled: 0.0000 (7.0119)  loss_bbox_unscaled: 0.0483 (0.0542)  loss_giou_unscaled: 0.1179 (0.1141)  cardinality_error_unscaled: 1986.7500 (3068.0423)  loss_ce_0_unscaled: 0.6468 (0.8847)  loss_bbox_0_unscaled: 0.0516 (0.0545)  loss_giou_0_unscaled: 0.1032 (0.1171)  cardinality_error_0_unscaled: 2134.2500 (3227.3682)  loss_ce_enc_unscaled: 0.6153 (0.9512)  loss_bbox_enc_unscaled: 0.0857 (0.0916)  loss_giou_enc_unscaled: 0.1626 (0.1563)  cardinality_error_enc_unscaled: 3370.7500 (3702.6132)  time: 2.4460  data: 0.0041  max mem: 4650
# Epoch: [0]  [ 210/1029]  eta: 0:34:29  lr: 0.000100  class_error: 0.70  loss: 3.2732 (4.2116)  loss_ce: 0.4680 (0.6378)  loss_bbox: 0.2454 (0.2711)  loss_giou: 0.1536 (0.2249)  loss_ce_0: 0.6289 (0.8729)  loss_bbox_0: 0.2582 (0.2727)  loss_giou_0: 0.1623 (0.2307)  loss_ce_enc: 0.6085 (0.9350)  loss_bbox_enc: 0.4412 (0.4579)  loss_giou_enc: 0.2414 (0.3087)  loss_ce_unscaled: 0.4680 (0.6378)  class_error_unscaled: 0.0000 (6.7423)  loss_bbox_unscaled: 0.0491 (0.0542)  loss_giou_unscaled: 0.0768 (0.1124)  cardinality_error_unscaled: 2425.7500 (3047.4230)  loss_ce_0_unscaled: 0.6289 (0.8729)  loss_bbox_0_unscaled: 0.0516 (0.0545)  loss_giou_0_unscaled: 0.0811 (0.1153)  cardinality_error_0_unscaled: 2517.0000 (3202.9479)  loss_ce_enc_unscaled: 0.6085 (0.9350)  loss_bbox_enc_unscaled: 0.0882 (0.0916)  loss_giou_enc_unscaled: 0.1207 (0.1543)  cardinality_error_enc_unscaled: 3403.2500 (3688.2109)  time: 2.4725  data: 0.0042  max mem: 4650
# Epoch: [0]  [ 220/1029]  eta: 0:33:57  lr: 0.000100  class_error: 0.00  loss: 3.2472 (4.1727)  loss_ce: 0.4687 (0.6313)  loss_bbox: 0.2213 (0.2698)  loss_giou: 0.1890 (0.2243)  loss_ce_0: 0.6163 (0.8619)  loss_bbox_0: 0.2268 (0.2703)  loss_giou_0: 0.1662 (0.2295)  loss_ce_enc: 0.6067 (0.9207)  loss_bbox_enc: 0.4388 (0.4569)  loss_giou_enc: 0.2393 (0.3082)  loss_ce_unscaled: 0.4687 (0.6313)  class_error_unscaled: 0.0000 (6.5045)  loss_bbox_unscaled: 0.0443 (0.0540)  loss_giou_unscaled: 0.0945 (0.1121)  cardinality_error_unscaled: 2635.7500 (3026.2805)  loss_ce_0_unscaled: 0.6163 (0.8619)  loss_bbox_0_unscaled: 0.0454 (0.0541)  loss_giou_0_unscaled: 0.0831 (0.1147)  cardinality_error_0_unscaled: 2599.7500 (3174.0486)  loss_ce_enc_unscaled: 0.6067 (0.9207)  loss_bbox_enc_unscaled: 0.0878 (0.0914)  loss_giou_enc_unscaled: 0.1197 (0.1541)  cardinality_error_enc_unscaled: 3447.0000 (3678.2986)  time: 2.3397  data: 0.0041  max mem: 4650
# Epoch: [0]  [ 230/1029]  eta: 0:33:25  lr: 0.000100  class_error: 16.67  loss: 3.3030 (4.1351)  loss_ce: 0.4691 (0.6222)  loss_bbox: 0.2489 (0.2693)  loss_giou: 0.1992 (0.2236)  loss_ce_0: 0.6343 (0.8513)  loss_bbox_0: 0.2182 (0.2697)  loss_giou_0: 0.1953 (0.2287)  loss_ce_enc: 0.5975 (0.9061)  loss_bbox_enc: 0.4363 (0.4570)  loss_giou_enc: 0.2735 (0.3071)  loss_ce_unscaled: 0.4691 (0.6222)  class_error_unscaled: 0.0000 (6.3576)  loss_bbox_unscaled: 0.0498 (0.0539)  loss_giou_unscaled: 0.0996 (0.1118)  cardinality_error_unscaled: 2542.2500 (2999.1634)  loss_ce_0_unscaled: 0.6343 (0.8513)  loss_bbox_0_unscaled: 0.0436 (0.0539)  loss_giou_0_unscaled: 0.0977 (0.1143)  cardinality_error_0_unscaled: 2431.5000 (3133.3701)  loss_ce_enc_unscaled: 0.5975 (0.9061)  loss_bbox_enc_unscaled: 0.0873 (0.0914)  loss_giou_enc_unscaled: 0.1367 (0.1535)  cardinality_error_enc_unscaled: 3464.0000 (3665.5465)  time: 2.3394  data: 0.0041  max mem: 4650
# Epoch: [0]  [ 240/1029]  eta: 0:33:02  lr: 0.000100  class_error: 0.85  loss: 3.0486 (4.0887)  loss_ce: 0.4691 (0.6156)  loss_bbox: 0.2289 (0.2668)  loss_giou: 0.1719 (0.2231)  loss_ce_0: 0.5905 (0.8398)  loss_bbox_0: 0.2012 (0.2667)  loss_giou_0: 0.1844 (0.2278)  loss_ce_enc: 0.5563 (0.8917)  loss_bbox_enc: 0.3664 (0.4518)  loss_giou_enc: 0.2325 (0.3055)  loss_ce_unscaled: 0.4691 (0.6156)  class_error_unscaled: 0.0000 (6.2658)  loss_bbox_unscaled: 0.0458 (0.0534)  loss_giou_unscaled: 0.0860 (0.1116)  cardinality_error_unscaled: 2471.0000 (2979.9056)  loss_ce_0_unscaled: 0.5905 (0.8398)  loss_bbox_0_unscaled: 0.0402 (0.0533)  loss_giou_0_unscaled: 0.0922 (0.1139)  cardinality_error_0_unscaled: 2374.7500 (3104.4990)  loss_ce_enc_unscaled: 0.5563 (0.8917)  loss_bbox_enc_unscaled: 0.0733 (0.0904)  loss_giou_enc_unscaled: 0.1163 (0.1527)  cardinality_error_enc_unscaled: 3448.0000 (3654.2656)  time: 2.4401  data: 0.0043  max mem: 4650
# Epoch: [0]  [ 250/1029]  eta: 0:32:36  lr: 0.000100  class_error: 0.00  loss: 3.0486 (4.0496)  loss_ce: 0.4493 (0.6077)  loss_bbox: 0.2280 (0.2670)  loss_giou: 0.1980 (0.2221)  loss_ce_0: 0.5628 (0.8281)  loss_bbox_0: 0.2166 (0.2670)  loss_giou_0: 0.1904 (0.2267)  loss_ce_enc: 0.5563 (0.8771)  loss_bbox_enc: 0.3465 (0.4503)  loss_giou_enc: 0.2453 (0.3035)  loss_ce_unscaled: 0.4493 (0.6077)  class_error_unscaled: 0.0000 (6.0162)  loss_bbox_unscaled: 0.0456 (0.0534)  loss_giou_unscaled: 0.0990 (0.1110)  cardinality_error_unscaled: 2491.2500 (2964.0448)  loss_ce_0_unscaled: 0.5628 (0.8281)  loss_bbox_0_unscaled: 0.0433 (0.0534)  loss_giou_0_unscaled: 0.0952 (0.1133)  cardinality_error_0_unscaled: 2431.7500 (3077.7271)  loss_ce_enc_unscaled: 0.5563 (0.8771)  loss_bbox_enc_unscaled: 0.0693 (0.0901)  loss_giou_enc_unscaled: 0.1226 (0.1517)  cardinality_error_enc_unscaled: 3374.5000 (3643.3237)  time: 2.5209  data: 0.0044  max mem: 4650
# Epoch: [0]  [ 260/1029]  eta: 0:32:12  lr: 0.000100  class_error: 5.38  loss: 2.9651 (4.0080)  loss_ce: 0.3287 (0.5981)  loss_bbox: 0.2321 (0.2654)  loss_giou: 0.1980 (0.2218)  loss_ce_0: 0.4985 (0.8157)  loss_bbox_0: 0.2299 (0.2655)  loss_giou_0: 0.1959 (0.2261)  loss_ce_enc: 0.5053 (0.8629)  loss_bbox_enc: 0.3839 (0.4496)  loss_giou_enc: 0.2478 (0.3030)  loss_ce_unscaled: 0.3287 (0.5981)  class_error_unscaled: 0.0000 (5.8243)  loss_bbox_unscaled: 0.0464 (0.0531)  loss_giou_unscaled: 0.0990 (0.1109)  cardinality_error_unscaled: 2609.2500 (2956.2864)  loss_ce_0_unscaled: 0.4985 (0.8157)  loss_bbox_0_unscaled: 0.0460 (0.0531)  loss_giou_0_unscaled: 0.0980 (0.1130)  cardinality_error_0_unscaled: 2472.0000 (3056.0862)  loss_ce_enc_unscaled: 0.5053 (0.8629)  loss_bbox_enc_unscaled: 0.0768 (0.0899)  loss_giou_enc_unscaled: 0.1239 (0.1515)  cardinality_error_enc_unscaled: 3531.2500 (3641.9521)  time: 2.5140  data: 0.0048  max mem: 4650
# Epoch: [0]  [ 270/1029]  eta: 0:31:43  lr: 0.000100  class_error: 0.00  loss: 2.8626 (3.9621)  loss_ce: 0.3387 (0.5891)  loss_bbox: 0.2012 (0.2627)  loss_giou: 0.1930 (0.2208)  loss_ce_0: 0.4688 (0.8026)  loss_bbox_0: 0.1916 (0.2631)  loss_giou_0: 0.1937 (0.2248)  loss_ce_enc: 0.4862 (0.8495)  loss_bbox_enc: 0.4042 (0.4474)  loss_giou_enc: 0.2835 (0.3020)  loss_ce_unscaled: 0.3387 (0.5891)  class_error_unscaled: 0.0000 (5.6602)  loss_bbox_unscaled: 0.0402 (0.0525)  loss_giou_unscaled: 0.0965 (0.1104)  cardinality_error_unscaled: 2609.2500 (2939.6780)  loss_ce_0_unscaled: 0.4688 (0.8026)  loss_bbox_0_unscaled: 0.0383 (0.0526)  loss_giou_0_unscaled: 0.0969 (0.1124)  cardinality_error_0_unscaled: 2404.0000 (3027.2315)  loss_ce_enc_unscaled: 0.4862 (0.8495)  loss_bbox_enc_unscaled: 0.0808 (0.0895)  loss_giou_enc_unscaled: 0.1417 (0.1510)  cardinality_error_enc_unscaled: 3587.0000 (3636.0461)  time: 2.4679  data: 0.0054  max mem: 4650
# Epoch: [0]  [ 280/1029]  eta: 0:31:10  lr: 0.000100  class_error: 0.00  loss: 2.9670 (3.9405)  loss_ce: 0.3604 (0.5829)  loss_bbox: 0.2045 (0.2646)  loss_giou: 0.2156 (0.2213)  loss_ce_0: 0.4933 (0.7929)  loss_bbox_0: 0.2007 (0.2648)  loss_giou_0: 0.2063 (0.2249)  loss_ce_enc: 0.5217 (0.8392)  loss_bbox_enc: 0.3971 (0.4482)  loss_giou_enc: 0.2859 (0.3016)  loss_ce_unscaled: 0.3604 (0.5829)  class_error_unscaled: 0.0000 (5.4679)  loss_bbox_unscaled: 0.0409 (0.0529)  loss_giou_unscaled: 0.1078 (0.1106)  cardinality_error_unscaled: 2312.5000 (2912.7838)  loss_ce_0_unscaled: 0.4933 (0.7929)  loss_bbox_0_unscaled: 0.0401 (0.0530)  loss_giou_0_unscaled: 0.1032 (0.1125)  cardinality_error_0_unscaled: 2113.0000 (2991.8025)  loss_ce_enc_unscaled: 0.5217 (0.8392)  loss_bbox_enc_unscaled: 0.0794 (0.0896)  loss_giou_enc_unscaled: 0.1430 (0.1508)  cardinality_error_enc_unscaled: 3323.5000 (3620.7678)  time: 2.2975  data: 0.0054  max mem: 4650
# Epoch: [0]  [ 290/1029]  eta: 0:30:44  lr: 0.000100  class_error: 0.00  loss: 3.3343 (3.9130)  loss_ce: 0.4659 (0.5785)  loss_bbox: 0.2427 (0.2633)  loss_giou: 0.2057 (0.2203)  loss_ce_0: 0.5653 (0.7858)  loss_bbox_0: 0.2358 (0.2633)  loss_giou_0: 0.2063 (0.2238)  loss_ce_enc: 0.5619 (0.8301)  loss_bbox_enc: 0.4181 (0.4471)  loss_giou_enc: 0.2759 (0.3006)  loss_ce_unscaled: 0.4659 (0.5785)  class_error_unscaled: 0.0000 (5.3456)  loss_bbox_unscaled: 0.0485 (0.0527)  loss_giou_unscaled: 0.1029 (0.1102)  cardinality_error_unscaled: 2106.5000 (2889.0344)  loss_ce_0_unscaled: 0.5653 (0.7858)  loss_bbox_0_unscaled: 0.0472 (0.0527)  loss_giou_0_unscaled: 0.1032 (0.1119)  cardinality_error_0_unscaled: 2018.0000 (2962.3840)  loss_ce_enc_unscaled: 0.5619 (0.8301)  loss_bbox_enc_unscaled: 0.0836 (0.0894)  loss_giou_enc_unscaled: 0.1380 (0.1503)  cardinality_error_enc_unscaled: 3285.5000 (3608.0155)  time: 2.3352  data: 0.0046  max mem: 4650
# Epoch: [0]  [ 300/1029]  eta: 0:30:17  lr: 0.000100  class_error: -0.00  loss: 2.9320 (3.8765)  loss_ce: 0.3822 (0.5713)  loss_bbox: 0.2295 (0.2626)  loss_giou: 0.1685 (0.2187)  loss_ce_0: 0.5361 (0.7756)  loss_bbox_0: 0.2300 (0.2622)  loss_giou_0: 0.1707 (0.2219)  loss_ce_enc: 0.5215 (0.8190)  loss_bbox_enc: 0.4221 (0.4464)  loss_giou_enc: 0.2464 (0.2988)  loss_ce_unscaled: 0.3822 (0.5713)  class_error_unscaled: 0.0000 (5.2479)  loss_bbox_unscaled: 0.0459 (0.0525)  loss_giou_unscaled: 0.0843 (0.1094)  cardinality_error_unscaled: 2390.7500 (2872.7168)  loss_ce_0_unscaled: 0.5361 (0.7756)  loss_bbox_0_unscaled: 0.0460 (0.0524)  loss_giou_0_unscaled: 0.0854 (0.1109)  cardinality_error_0_unscaled: 2235.5000 (2940.4369)  loss_ce_enc_unscaled: 0.5215 (0.8190)  loss_bbox_enc_unscaled: 0.0844 (0.0893)  loss_giou_enc_unscaled: 0.1232 (0.1494)  cardinality_error_enc_unscaled: 3285.5000 (3600.1071)  time: 2.4460  data: 0.0046  max mem: 4650
# Epoch: [0]  [ 310/1029]  eta: 0:29:49  lr: 0.000100  class_error: 0.00  loss: 2.6447 (3.8358)  loss_ce: 0.3541 (0.5629)  loss_bbox: 0.2136 (0.2614)  loss_giou: 0.1607 (0.2171)  loss_ce_0: 0.4288 (0.7639)  loss_bbox_0: 0.2289 (0.2609)  loss_giou_0: 0.1616 (0.2203)  loss_ce_enc: 0.4648 (0.8064)  loss_bbox_enc: 0.3869 (0.4456)  loss_giou_enc: 0.2237 (0.2973)  loss_ce_unscaled: 0.3541 (0.5629)  class_error_unscaled: 0.0000 (5.0791)  loss_bbox_unscaled: 0.0427 (0.0523)  loss_giou_unscaled: 0.0804 (0.1086)  cardinality_error_unscaled: 2558.7500 (2861.7347)  loss_ce_0_unscaled: 0.4288 (0.7639)  loss_bbox_0_unscaled: 0.0458 (0.0522)  loss_giou_0_unscaled: 0.0808 (0.1101)  cardinality_error_0_unscaled: 2235.5000 (2915.9654)  loss_ce_enc_unscaled: 0.4648 (0.8064)  loss_bbox_enc_unscaled: 0.0774 (0.0891)  loss_giou_enc_unscaled: 0.1119 (0.1486)  cardinality_error_enc_unscaled: 3415.2500 (3591.8288)  time: 2.3885  data: 0.0046  max mem: 4650
# Epoch: [0]  [ 320/1029]  eta: 0:29:26  lr: 0.000100  class_error: -0.00  loss: 2.8411 (3.8077)  loss_ce: 0.3379 (0.5573)  loss_bbox: 0.2136 (0.2612)  loss_giou: 0.1730 (0.2155)  loss_ce_0: 0.4501 (0.7563)  loss_bbox_0: 0.2008 (0.2602)  loss_giou_0: 0.1621 (0.2181)  loss_ce_enc: 0.4840 (0.7974)  loss_bbox_enc: 0.3869 (0.4461)  loss_giou_enc: 0.2429 (0.2956)  loss_ce_unscaled: 0.3379 (0.5573)  class_error_unscaled: 0.0000 (4.9209)  loss_bbox_unscaled: 0.0427 (0.0522)  loss_giou_unscaled: 0.0865 (0.1077)  cardinality_error_unscaled: 2710.0000 (2860.4525)  loss_ce_0_unscaled: 0.4501 (0.7563)  loss_bbox_0_unscaled: 0.0402 (0.0520)  loss_giou_0_unscaled: 0.0810 (0.1091)  cardinality_error_0_unscaled: 2251.2500 (2898.7422)  loss_ce_enc_unscaled: 0.4840 (0.7974)  loss_bbox_enc_unscaled: 0.0774 (0.0892)  loss_giou_enc_unscaled: 0.1215 (0.1478)  cardinality_error_enc_unscaled: 3484.7500 (3583.4665)  time: 2.4557  data: 0.0051  max mem: 4650
# Epoch: [0]  [ 330/1029]  eta: 0:29:02  lr: 0.000100  class_error: 9.23  loss: 2.9374 (3.7870)  loss_ce: 0.3646 (0.5515)  loss_bbox: 0.2401 (0.2620)  loss_giou: 0.1730 (0.2155)  loss_ce_0: 0.4915 (0.7473)  loss_bbox_0: 0.2096 (0.2608)  loss_giou_0: 0.1621 (0.2180)  loss_ce_enc: 0.5109 (0.7887)  loss_bbox_enc: 0.4290 (0.4473)  loss_giou_enc: 0.2764 (0.2958)  loss_ce_unscaled: 0.3646 (0.5515)  class_error_unscaled: 0.0000 (4.8272)  loss_bbox_unscaled: 0.0480 (0.0524)  loss_giou_unscaled: 0.0865 (0.1078)  cardinality_error_unscaled: 2841.7500 (2848.4645)  loss_ce_0_unscaled: 0.4915 (0.7473)  loss_bbox_0_unscaled: 0.0419 (0.0522)  loss_giou_0_unscaled: 0.0810 (0.1090)  cardinality_error_0_unscaled: 2282.2500 (2875.2840)  loss_ce_enc_unscaled: 0.5109 (0.7887)  loss_bbox_enc_unscaled: 0.0858 (0.0895)  loss_giou_enc_unscaled: 0.1382 (0.1479)  cardinality_error_enc_unscaled: 3306.5000 (3565.2666)  time: 2.5496  data: 0.0055  max mem: 4650
# Epoch: [0]  [ 340/1029]  eta: 0:28:30  lr: 0.000100  class_error: 0.00  loss: 2.9201 (3.7545)  loss_ce: 0.3646 (0.5452)  loss_bbox: 0.2237 (0.2617)  loss_giou: 0.1662 (0.2137)  loss_ce_0: 0.4922 (0.7389)  loss_bbox_0: 0.2156 (0.2602)  loss_giou_0: 0.1707 (0.2159)  loss_ce_enc: 0.4881 (0.7791)  loss_bbox_enc: 0.4080 (0.4461)  loss_giou_enc: 0.2764 (0.2938)  loss_ce_unscaled: 0.3646 (0.5452)  class_error_unscaled: 0.0000 (4.6957)  loss_bbox_unscaled: 0.0447 (0.0523)  loss_giou_unscaled: 0.0831 (0.1069)  cardinality_error_unscaled: 2865.0000 (2852.7412)  loss_ce_0_unscaled: 0.4922 (0.7389)  loss_bbox_0_unscaled: 0.0431 (0.0520)  loss_giou_0_unscaled: 0.0854 (0.1079)  cardinality_error_0_unscaled: 2410.5000 (2864.6246)  loss_ce_enc_unscaled: 0.4881 (0.7791)  loss_bbox_enc_unscaled: 0.0816 (0.0892)  loss_giou_enc_unscaled: 0.1382 (0.1469)  cardinality_error_enc_unscaled: 3306.5000 (3558.7691)  time: 2.3360  data: 0.0050  max mem: 4650
# Epoch: [0]  [ 350/1029]  eta: 0:28:04  lr: 0.000100  class_error: 0.00  loss: 2.6847 (3.7316)  loss_ce: 0.3593 (0.5404)  loss_bbox: 0.2125 (0.2623)  loss_giou: 0.1681 (0.2129)  loss_ce_0: 0.4587 (0.7317)  loss_bbox_0: 0.2403 (0.2612)  loss_giou_0: 0.1851 (0.2152)  loss_ce_enc: 0.4768 (0.7701)  loss_bbox_enc: 0.3876 (0.4456)  loss_giou_enc: 0.2179 (0.2922)  loss_ce_unscaled: 0.3593 (0.5404)  class_error_unscaled: 0.0000 (4.5997)  loss_bbox_unscaled: 0.0425 (0.0525)  loss_giou_unscaled: 0.0840 (0.1064)  cardinality_error_unscaled: 2902.7500 (2854.4765)  loss_ce_0_unscaled: 0.4587 (0.7317)  loss_bbox_0_unscaled: 0.0481 (0.0522)  loss_giou_0_unscaled: 0.0926 (0.1076)  cardinality_error_0_unscaled: 2456.2500 (2849.6845)  loss_ce_enc_unscaled: 0.4768 (0.7701)  loss_bbox_enc_unscaled: 0.0775 (0.0891)  loss_giou_enc_unscaled: 0.1090 (0.1461)  cardinality_error_enc_unscaled: 3522.0000 (3560.5278)  time: 2.2737  data: 0.0058  max mem: 4650
# Epoch: [0]  [ 360/1029]  eta: 0:27:34  lr: 0.000100  class_error: 0.00  loss: 2.6709 (3.6994)  loss_ce: 0.3593 (0.5349)  loss_bbox: 0.2220 (0.2611)  loss_giou: 0.1681 (0.2118)  loss_ce_0: 0.4587 (0.7236)  loss_bbox_0: 0.2612 (0.2597)  loss_giou_0: 0.1885 (0.2140)  loss_ce_enc: 0.4768 (0.7613)  loss_bbox_enc: 0.3685 (0.4426)  loss_giou_enc: 0.2235 (0.2904)  loss_ce_unscaled: 0.3593 (0.5349)  class_error_unscaled: 0.0000 (4.5069)  loss_bbox_unscaled: 0.0444 (0.0522)  loss_giou_unscaled: 0.0840 (0.1059)  cardinality_error_unscaled: 2288.0000 (2827.8747)  loss_ce_0_unscaled: 0.4587 (0.7236)  loss_bbox_0_unscaled: 0.0522 (0.0519)  loss_giou_0_unscaled: 0.0943 (0.1070)  cardinality_error_0_unscaled: 1738.0000 (2813.9668)  loss_ce_enc_unscaled: 0.4768 (0.7613)  loss_bbox_enc_unscaled: 0.0737 (0.0885)  loss_giou_enc_unscaled: 0.1118 (0.1452)  cardinality_error_enc_unscaled: 3500.5000 (3555.1447)  time: 2.3119  data: 0.0061  max mem: 4650
# Epoch: [0]  [ 370/1029]  eta: 0:27:07  lr: 0.000100  class_error: 0.00  loss: 2.6694 (3.6751)  loss_ce: 0.3375 (0.5301)  loss_bbox: 0.2084 (0.2603)  loss_giou: 0.1821 (0.2114)  loss_ce_0: 0.4262 (0.7158)  loss_bbox_0: 0.2090 (0.2587)  loss_giou_0: 0.1885 (0.2135)  loss_ce_enc: 0.4908 (0.7542)  loss_bbox_enc: 0.3620 (0.4411)  loss_giou_enc: 0.2235 (0.2900)  loss_ce_unscaled: 0.3375 (0.5301)  class_error_unscaled: 0.0000 (4.3984)  loss_bbox_unscaled: 0.0417 (0.0521)  loss_giou_unscaled: 0.0911 (0.1057)  cardinality_error_unscaled: 2025.7500 (2805.1247)  loss_ce_0_unscaled: 0.4262 (0.7158)  loss_bbox_0_unscaled: 0.0418 (0.0517)  loss_giou_0_unscaled: 0.0943 (0.1067)  cardinality_error_0_unscaled: 1354.5000 (2772.5391)  loss_ce_enc_unscaled: 0.4908 (0.7542)  loss_bbox_enc_unscaled: 0.0724 (0.0882)  loss_giou_enc_unscaled: 0.1118 (0.1450)  cardinality_error_enc_unscaled: 3361.7500 (3547.6307)  time: 2.2892  data: 0.0054  max mem: 4650
# Epoch: [0]  [ 380/1029]  eta: 0:26:36  lr: 0.000100  class_error: 0.00  loss: 2.7922 (3.6439)  loss_ce: 0.3486 (0.5246)  loss_bbox: 0.2427 (0.2603)  loss_giou: 0.1905 (0.2102)  loss_ce_0: 0.3937 (0.7066)  loss_bbox_0: 0.2168 (0.2583)  loss_giou_0: 0.1772 (0.2122)  loss_ce_enc: 0.4785 (0.7450)  loss_bbox_enc: 0.3656 (0.4388)  loss_giou_enc: 0.2207 (0.2879)  loss_ce_unscaled: 0.3486 (0.5246)  class_error_unscaled: 0.0000 (4.3205)  loss_bbox_unscaled: 0.0485 (0.0521)  loss_giou_unscaled: 0.0952 (0.1051)  cardinality_error_unscaled: 2328.0000 (2803.6247)  loss_ce_0_unscaled: 0.3937 (0.7066)  loss_bbox_0_unscaled: 0.0434 (0.0517)  loss_giou_0_unscaled: 0.0886 (0.1061)  cardinality_error_0_unscaled: 1462.5000 (2748.7028)  loss_ce_enc_unscaled: 0.4785 (0.7450)  loss_bbox_enc_unscaled: 0.0731 (0.0878)  loss_giou_enc_unscaled: 0.1104 (0.1439)  cardinality_error_enc_unscaled: 3361.7500 (3544.5190)  time: 2.2284  data: 0.0050  max mem: 4650
# Epoch: [0]  [ 390/1029]  eta: 0:26:16  lr: 0.000100  class_error: -0.00  loss: 2.7922 (3.6201)  loss_ce: 0.3633 (0.5202)  loss_bbox: 0.2527 (0.2601)  loss_giou: 0.1311 (0.2092)  loss_ce_0: 0.4274 (0.7003)  loss_bbox_0: 0.2290 (0.2579)  loss_giou_0: 0.1274 (0.2110)  loss_ce_enc: 0.4542 (0.7381)  loss_bbox_enc: 0.3594 (0.4370)  loss_giou_enc: 0.2149 (0.2862)  loss_ce_unscaled: 0.3633 (0.5202)  class_error_unscaled: 0.0000 (4.2143)  loss_bbox_unscaled: 0.0505 (0.0520)  loss_giou_unscaled: 0.0656 (0.1046)  cardinality_error_unscaled: 2820.7500 (2807.8069)  loss_ce_0_unscaled: 0.4274 (0.7003)  loss_bbox_0_unscaled: 0.0458 (0.0516)  loss_giou_0_unscaled: 0.0637 (0.1055)  cardinality_error_0_unscaled: 2172.0000 (2745.1023)  loss_ce_enc_unscaled: 0.4542 (0.7381)  loss_bbox_enc_unscaled: 0.0719 (0.0874)  loss_giou_enc_unscaled: 0.1074 (0.1431)  cardinality_error_enc_unscaled: 3378.0000 (3540.2219)  time: 2.4143  data: 0.0049  max mem: 4650
# Epoch: [0]  [ 400/1029]  eta: 0:25:48  lr: 0.000100  class_error: 3.42  loss: 2.5001 (3.5872)  loss_ce: 0.3234 (0.5146)  loss_bbox: 0.2085 (0.2585)  loss_giou: 0.1311 (0.2080)  loss_ce_0: 0.3833 (0.6920)  loss_bbox_0: 0.2039 (0.2564)  loss_giou_0: 0.1274 (0.2098)  loss_ce_enc: 0.4002 (0.7291)  loss_bbox_enc: 0.3187 (0.4343)  loss_giou_enc: 0.2008 (0.2844)  loss_ce_unscaled: 0.3234 (0.5146)  class_error_unscaled: 0.0000 (4.1178)  loss_bbox_unscaled: 0.0417 (0.0517)  loss_giou_unscaled: 0.0656 (0.1040)  cardinality_error_unscaled: 2678.0000 (2801.8180)  loss_ce_0_unscaled: 0.3833 (0.6920)  loss_bbox_0_unscaled: 0.0408 (0.0513)  loss_giou_0_unscaled: 0.0637 (0.1049)  cardinality_error_0_unscaled: 2294.5000 (2730.0835)  loss_ce_enc_unscaled: 0.4002 (0.7291)  loss_bbox_enc_unscaled: 0.0637 (0.0869)  loss_giou_enc_unscaled: 0.1004 (0.1422)  cardinality_error_enc_unscaled: 3303.2500 (3535.0599)  time: 2.4944  data: 0.0049  max mem: 4650
# Epoch: [0]  [ 410/1029]  eta: 0:25:23  lr: 0.000100  class_error: 0.00  loss: 2.5130 (3.5699)  loss_ce: 0.3222 (0.5110)  loss_bbox: 0.2085 (0.2582)  loss_giou: 0.1782 (0.2078)  loss_ce_0: 0.3833 (0.6862)  loss_bbox_0: 0.2039 (0.2561)  loss_giou_0: 0.1945 (0.2095)  loss_ce_enc: 0.4064 (0.7227)  loss_bbox_enc: 0.3474 (0.4342)  loss_giou_enc: 0.2498 (0.2842)  loss_ce_unscaled: 0.3222 (0.5110)  class_error_unscaled: 0.0000 (4.0227)  loss_bbox_unscaled: 0.0417 (0.0516)  loss_giou_unscaled: 0.0891 (0.1039)  cardinality_error_unscaled: 2345.0000 (2787.1107)  loss_ce_0_unscaled: 0.3833 (0.6862)  loss_bbox_0_unscaled: 0.0408 (0.0512)  loss_giou_0_unscaled: 0.0973 (0.1048)  cardinality_error_0_unscaled: 1892.7500 (2709.3686)  loss_ce_enc_unscaled: 0.4064 (0.7227)  loss_bbox_enc_unscaled: 0.0695 (0.0868)  loss_giou_enc_unscaled: 0.1249 (0.1421)  cardinality_error_enc_unscaled: 3249.0000 (3524.6356)  time: 2.3467  data: 0.0050  max mem: 4650
# Epoch: [0]  [ 420/1029]  eta: 0:24:59  lr: 0.000100  class_error: 0.00  loss: 2.7156 (3.5503)  loss_ce: 0.3644 (0.5080)  loss_bbox: 0.2163 (0.2576)  loss_giou: 0.1935 (0.2072)  loss_ce_0: 0.4285 (0.6800)  loss_bbox_0: 0.2093 (0.2552)  loss_giou_0: 0.2036 (0.2086)  loss_ce_enc: 0.4345 (0.7166)  loss_bbox_enc: 0.4031 (0.4338)  loss_giou_enc: 0.2787 (0.2833)  loss_ce_unscaled: 0.3644 (0.5080)  class_error_unscaled: 0.0000 (3.9348)  loss_bbox_unscaled: 0.0433 (0.0515)  loss_giou_unscaled: 0.0968 (0.1036)  cardinality_error_unscaled: 1878.7500 (2765.9400)  loss_ce_0_unscaled: 0.4285 (0.6800)  loss_bbox_0_unscaled: 0.0419 (0.0510)  loss_giou_0_unscaled: 0.1018 (0.1043)  cardinality_error_0_unscaled: 1657.0000 (2682.1205)  loss_ce_enc_unscaled: 0.4345 (0.7166)  loss_bbox_enc_unscaled: 0.0806 (0.0868)  loss_giou_enc_unscaled: 0.1394 (0.1417)  cardinality_error_enc_unscaled: 3004.7500 (3508.2530)  time: 2.4684  data: 0.0056  max mem: 4650
# Epoch: [0]  [ 430/1029]  eta: 0:24:35  lr: 0.000100  class_error: 0.00  loss: 2.9504 (3.5350)  loss_ce: 0.3644 (0.5036)  loss_bbox: 0.2292 (0.2578)  loss_giou: 0.1660 (0.2069)  loss_ce_0: 0.4392 (0.6734)  loss_bbox_0: 0.2399 (0.2556)  loss_giou_0: 0.1621 (0.2084)  loss_ce_enc: 0.4550 (0.7105)  loss_bbox_enc: 0.4525 (0.4353)  loss_giou_enc: 0.2283 (0.2834)  loss_ce_unscaled: 0.3644 (0.5036)  class_error_unscaled: 0.0000 (3.8721)  loss_bbox_unscaled: 0.0458 (0.0516)  loss_giou_unscaled: 0.0830 (0.1035)  cardinality_error_unscaled: 2157.5000 (2754.5806)  loss_ce_0_unscaled: 0.4392 (0.6734)  loss_bbox_0_unscaled: 0.0480 (0.0511)  loss_giou_0_unscaled: 0.0810 (0.1042)  cardinality_error_0_unscaled: 1551.5000 (2659.0887)  loss_ce_enc_unscaled: 0.4550 (0.7105)  loss_bbox_enc_unscaled: 0.0905 (0.0871)  loss_giou_enc_unscaled: 0.1142 (0.1417)  cardinality_error_enc_unscaled: 3004.7500 (3498.3376)  time: 2.4929  data: 0.0061  max mem: 4650
# Epoch: [0]  [ 440/1029]  eta: 0:24:09  lr: 0.000100  class_error: 0.00  loss: 2.8142 (3.5169)  loss_ce: 0.3405 (0.5003)  loss_bbox: 0.2496 (0.2573)  loss_giou: 0.1647 (0.2065)  loss_ce_0: 0.4136 (0.6675)  loss_bbox_0: 0.2623 (0.2553)  loss_giou_0: 0.1820 (0.2081)  loss_ce_enc: 0.4710 (0.7052)  loss_bbox_enc: 0.4203 (0.4339)  loss_giou_enc: 0.2283 (0.2828)  loss_ce_unscaled: 0.3405 (0.5003)  class_error_unscaled: 0.0000 (3.8393)  loss_bbox_unscaled: 0.0499 (0.0515)  loss_giou_unscaled: 0.0823 (0.1033)  cardinality_error_unscaled: 2292.2500 (2743.8940)  loss_ce_0_unscaled: 0.4136 (0.6675)  loss_bbox_0_unscaled: 0.0525 (0.0511)  loss_giou_0_unscaled: 0.0910 (0.1040)  cardinality_error_0_unscaled: 1672.0000 (2637.8764)  loss_ce_enc_unscaled: 0.4710 (0.7052)  loss_bbox_enc_unscaled: 0.0841 (0.0868)  loss_giou_enc_unscaled: 0.1142 (0.1414)  cardinality_error_enc_unscaled: 3013.0000 (3486.3991)  time: 2.4277  data: 0.0062  max mem: 4650
# Epoch: [0]  [ 450/1029]  eta: 0:23:41  lr: 0.000100  class_error: -0.00  loss: 2.7736 (3.5068)  loss_ce: 0.4066 (0.4992)  loss_bbox: 0.2281 (0.2572)  loss_giou: 0.1647 (0.2068)  loss_ce_0: 0.4439 (0.6643)  loss_bbox_0: 0.2208 (0.2548)  loss_giou_0: 0.1803 (0.2080)  loss_ce_enc: 0.4879 (0.7021)  loss_bbox_enc: 0.3455 (0.4319)  loss_giou_enc: 0.2250 (0.2824)  loss_ce_unscaled: 0.4066 (0.4992)  class_error_unscaled: 0.0000 (3.7833)  loss_bbox_unscaled: 0.0456 (0.0514)  loss_giou_unscaled: 0.0823 (0.1034)  cardinality_error_unscaled: 2501.0000 (2740.8570)  loss_ce_0_unscaled: 0.4439 (0.6643)  loss_bbox_0_unscaled: 0.0442 (0.0510)  loss_giou_0_unscaled: 0.0902 (0.1040)  cardinality_error_0_unscaled: 1936.5000 (2627.9557)  loss_ce_enc_unscaled: 0.4879 (0.7021)  loss_bbox_enc_unscaled: 0.0691 (0.0864)  loss_giou_enc_unscaled: 0.1125 (0.1412)  cardinality_error_enc_unscaled: 2923.2500 (3472.6336)  time: 2.3062  data: 0.0058  max mem: 4650
# Epoch: [0]  [ 460/1029]  eta: 0:23:14  lr: 0.000100  class_error: 0.00  loss: 3.1327 (3.5008)  loss_ce: 0.4620 (0.4980)  loss_bbox: 0.2022 (0.2565)  loss_giou: 0.1835 (0.2074)  loss_ce_0: 0.5907 (0.6624)  loss_bbox_0: 0.2076 (0.2545)  loss_giou_0: 0.1831 (0.2087)  loss_ce_enc: 0.5590 (0.6997)  loss_bbox_enc: 0.3268 (0.4307)  loss_giou_enc: 0.2562 (0.2830)  loss_ce_unscaled: 0.4620 (0.4980)  class_error_unscaled: 0.0000 (3.7029)  loss_bbox_unscaled: 0.0404 (0.0513)  loss_giou_unscaled: 0.0918 (0.1037)  cardinality_error_unscaled: 2591.5000 (2738.7326)  loss_ce_0_unscaled: 0.5907 (0.6624)  loss_bbox_0_unscaled: 0.0415 (0.0509)  loss_giou_0_unscaled: 0.0915 (0.1043)  cardinality_error_0_unscaled: 2208.5000 (2620.5499)  loss_ce_enc_unscaled: 0.5590 (0.6997)  loss_bbox_enc_unscaled: 0.0654 (0.0861)  loss_giou_enc_unscaled: 0.1281 (0.1415)  cardinality_error_enc_unscaled: 2785.0000 (3457.2923)  time: 2.2169  data: 0.0049  max mem: 4650
# ...
# Test:  [1005/1006]  eta: 0:00:00  class_error: 0.00  loss: 2.0532 (2.0133)  loss_ce: 0.2285 (0.2689)  loss_bbox: 0.2686 (0.1799)  loss_giou: 0.1353 (0.1686)  loss_ce_0: 0.2500 (0.2843)  loss_bbox_0: 0.2503 (0.1787)  loss_giou_0: 0.1277 (0.1668)  loss_ce_enc: 0.2910 (0.3403)  loss_bbox_enc: 0.2603 (0.2347)  loss_giou_enc: 0.1533 (0.1911)  loss_ce_unscaled: 0.2285 (0.2689)  class_error_unscaled: 0.0000 (0.4578)  loss_bbox_unscaled: 0.0537 (0.0360)  loss_giou_unscaled: 0.0676 (0.0843)  cardinality_error_unscaled: 231.7500 (187.8685)  loss_ce_0_unscaled: 0.2500 (0.2843)  loss_bbox_0_unscaled: 0.0501 (0.0357)  loss_giou_0_unscaled: 0.0638 (0.0834)  cardinality_error_0_unscaled: 175.5000 (120.8787)  loss_ce_enc_unscaled: 0.2910 (0.3403)  loss_bbox_enc_unscaled: 0.0521 (0.0469)  loss_giou_enc_unscaled: 0.0766 (0.0955)  cardinality_error_enc_unscaled: 251.5000 (205.2527)  time: 0.1532  data: 0.0037  max mem: 4650
# Test: Total time: 0:02:57 (0.1768 s / it)
# Averaged stats: class_error: 0.00  loss: 2.0532 (2.0133)  loss_ce: 0.2285 (0.2689)  loss_bbox: 0.2686 (0.1799)  loss_giou: 0.1353 (0.1686)  loss_ce_0: 0.2500 (0.2843)  loss_bbox_0: 0.2503 (0.1787)  loss_giou_0: 0.1277 (0.1668)  loss_ce_enc: 0.2910 (0.3403)  loss_bbox_enc: 0.2603 (0.2347)  loss_giou_enc: 0.1533 (0.1911)  loss_ce_unscaled: 0.2285 (0.2689)  class_error_unscaled: 0.0000 (0.4578)  loss_bbox_unscaled: 0.0537 (0.0360)  loss_giou_unscaled: 0.0676 (0.0843)  cardinality_error_unscaled: 231.7500 (187.8685)  loss_ce_0_unscaled: 0.2500 (0.2843)  loss_bbox_0_unscaled: 0.0501 (0.0357)  loss_giou_0_unscaled: 0.0638 (0.0834)  cardinality_error_0_unscaled: 175.5000 (120.8787)  loss_ce_enc_unscaled: 0.2910 (0.3403)  loss_bbox_enc_unscaled: 0.0521 (0.0469)  loss_giou_enc_unscaled: 0.0766 (0.0955)  cardinality_error_enc_unscaled: 251.5000 (205.2527)
# Accumulating evaluation results...
# DONE (t=7.47s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.783
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.691
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.666
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.731
# Early stopping: Current mAP (EMA): 0.6342, Best: 0.0000, Diff: 0.6342, Min delta: 0.001
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 1029
# Epoch: [1]  [   0/1029]  eta: 5:24:04  lr: 0.000100  class_error: 7.69  loss: 4.1269 (4.1269)  loss_ce: 0.7065 (0.7065)  loss_bbox: 0.4472 (0.4472)  loss_giou: 0.2337 (0.2337)  loss_ce_0: 0.6161 (0.6161)  loss_bbox_0: 0.4055 (0.4055)  loss_giou_0: 0.2139 (0.2139)  loss_ce_enc: 0.6581 (0.6581)  loss_bbox_enc: 0.5911 (0.5911)  loss_giou_enc: 0.2548 (0.2548)  loss_ce_unscaled: 0.7065 (0.7065)  class_error_unscaled: 7.6923 (7.6923)  loss_bbox_unscaled: 0.0894 (0.0894)  loss_giou_unscaled: 0.1169 (0.1169)  cardinality_error_unscaled: 3652.5000 (3652.5000)  loss_ce_0_unscaled: 0.6161 (0.6161)  loss_bbox_0_unscaled: 0.0811 (0.0811)  loss_giou_0_unscaled: 0.1069 (0.1069)  cardinality_error_0_unscaled: 3106.5000 (3106.5000)  loss_ce_enc_unscaled: 0.6581 (0.6581)  loss_bbox_enc_unscaled: 0.1182 (0.1182)  loss_giou_enc_unscaled: 0.1274 (0.1274)  cardinality_error_enc_unscaled: 3515.5000 (3515.5000)  time: 18.8966  data: 16.7577  max mem: 4650
# Epoch: [1]  [  10/1029]  eta: 1:08:24  lr: 0.000100  class_error: 0.00  loss: 2.9813 (2.9174)  loss_ce: 0.3960 (0.3825)  loss_bbox: 0.2608 (0.2799)  loss_giou: 0.1840 (0.2105)  loss_ce_0: 0.4513 (0.4215)  loss_bbox_0: 0.3184 (0.3173)  loss_giou_0: 0.2024 (0.2208)  loss_ce_enc: 0.4386 (0.4417)  loss_bbox_enc: 0.3880 (0.3884)  loss_giou_enc: 0.2316 (0.2548)  loss_ce_unscaled: 0.3960 (0.3825)  class_error_unscaled: 0.0000 (3.2051)  loss_bbox_unscaled: 0.0522 (0.0560)  loss_giou_unscaled: 0.0920 (0.1053)  cardinality_error_unscaled: 3107.0000 (3043.3409)  loss_ce_0_unscaled: 0.4513 (0.4215)  loss_bbox_0_unscaled: 0.0637 (0.0635)  loss_giou_0_unscaled: 0.1012 (0.1104)  cardinality_error_0_unscaled: 2773.7500 (2698.5682)  loss_ce_enc_unscaled: 0.4386 (0.4417)  loss_bbox_enc_unscaled: 0.0776 (0.0777)  loss_giou_enc_unscaled: 0.1158 (0.1274)  cardinality_error_enc_unscaled: 3087.2500 (3075.1364)  time: 4.0281  data: 1.5292  max mem: 4650
# Epoch: [1]  [  20/1029]  eta: 0:55:55  lr: 0.000100  class_error: 0.00  loss: 2.5302 (2.7303)  loss_ce: 0.3097 (0.3477)  loss_bbox: 0.2567 (0.2684)  loss_giou: 0.1667 (0.1980)  loss_ce_0: 0.3752 (0.3998)  loss_bbox_0: 0.2714 (0.2855)  loss_giou_0: 0.1722 (0.2027)  loss_ce_enc: 0.4378 (0.4296)  loss_bbox_enc: 0.3429 (0.3599)  loss_giou_enc: 0.2005 (0.2386)  loss_ce_unscaled: 0.3097 (0.3477)  class_error_unscaled: 0.0000 (2.1861)  loss_bbox_unscaled: 0.0513 (0.0537)  loss_giou_unscaled: 0.0834 (0.0990)  cardinality_error_unscaled: 3051.2500 (3024.7619)  loss_ce_0_unscaled: 0.3752 (0.3998)  loss_bbox_0_unscaled: 0.0543 (0.0571)  loss_giou_0_unscaled: 0.0861 (0.1014)  cardinality_error_0_unscaled: 2618.5000 (2655.4643)  loss_ce_enc_unscaled: 0.4378 (0.4296)  loss_bbox_enc_unscaled: 0.0686 (0.0720)  loss_giou_enc_unscaled: 0.1003 (0.1193)  cardinality_error_enc_unscaled: 3087.2500 (3088.5000)  time: 2.5471  data: 0.0055  max mem: 4650
# Epoch: [1]  [  30/1029]  eta: 0:48:30  lr: 0.000100  class_error: 1.92  loss: 2.4875 (2.7405)  loss_ce: 0.3153 (0.3457)  loss_bbox: 0.2488 (0.2632)  loss_giou: 0.1667 (0.2065)  loss_ce_0: 0.3752 (0.3955)  loss_bbox_0: 0.2520 (0.2760)  loss_giou_0: 0.1639 (0.2097)  loss_ce_enc: 0.4452 (0.4301)  loss_bbox_enc: 0.3429 (0.3631)  loss_giou_enc: 0.2005 (0.2506)  loss_ce_unscaled: 0.3153 (0.3457)  class_error_unscaled: 0.0000 (1.8117)  loss_bbox_unscaled: 0.0498 (0.0526)  loss_giou_unscaled: 0.0834 (0.1032)  cardinality_error_unscaled: 3156.0000 (3072.6694)  loss_ce_0_unscaled: 0.3752 (0.3955)  loss_bbox_0_unscaled: 0.0504 (0.0552)  loss_giou_0_unscaled: 0.0819 (0.1049)  cardinality_error_0_unscaled: 2483.7500 (2617.8226)  loss_ce_enc_unscaled: 0.4452 (0.4301)  loss_bbox_enc_unscaled: 0.0686 (0.0726)  loss_giou_enc_unscaled: 0.1003 (0.1253)  cardinality_error_enc_unscaled: 3265.7500 (3154.6129)  time: 2.2997  data: 0.0050  max mem: 4650
# Epoch: [1]  [  40/1029]  eta: 0:45:17  lr: 0.000100  class_error: 0.00  loss: 2.7323 (2.7392)  loss_ce: 0.3109 (0.3516)  loss_bbox: 0.2386 (0.2567)  loss_giou: 0.1617 (0.2020)  loss_ce_0: 0.3745 (0.3938)  loss_bbox_0: 0.2554 (0.2719)  loss_giou_0: 0.1671 (0.2056)  loss_ce_enc: 0.4211 (0.4272)  loss_bbox_enc: 0.3811 (0.3789)  loss_giou_enc: 0.2262 (0.2516)  loss_ce_unscaled: 0.3109 (0.3516)  class_error_unscaled: 0.0000 (1.3698)  loss_bbox_unscaled: 0.0477 (0.0513)  loss_giou_unscaled: 0.0809 (0.1010)  cardinality_error_unscaled: 3092.2500 (3092.7439)  loss_ce_0_unscaled: 0.3745 (0.3938)  loss_bbox_0_unscaled: 0.0511 (0.0544)  loss_giou_0_unscaled: 0.0835 (0.1028)  cardinality_error_0_unscaled: 2525.7500 (2600.8902)  loss_ce_enc_unscaled: 0.4211 (0.4272)  loss_bbox_enc_unscaled: 0.0762 (0.0758)  loss_giou_enc_unscaled: 0.1131 (0.1258)  cardinality_error_enc_unscaled: 3265.7500 (3173.1707)  time: 2.1408  data: 0.0052  max mem: 4650
# Epoch: [1]  [  50/1029]  eta: 0:44:30  lr: 0.000100  class_error: 0.00  loss: 2.7323 (2.7069)  loss_ce: 0.2906 (0.3539)  loss_bbox: 0.2145 (0.2448)  loss_giou: 0.1463 (0.1945)  loss_ce_0: 0.3512 (0.3942)  loss_bbox_0: 0.2198 (0.2577)  loss_giou_0: 0.1536 (0.1973)  loss_ce_enc: 0.4107 (0.4294)  loss_bbox_enc: 0.3811 (0.3840)  loss_giou_enc: 0.2153 (0.2510)  loss_ce_unscaled: 0.2906 (0.3539)  class_error_unscaled: 0.0000 (1.1012)  loss_bbox_unscaled: 0.0429 (0.0490)  loss_giou_unscaled: 0.0732 (0.0972)  cardinality_error_unscaled: 2967.0000 (3049.5196)  loss_ce_0_unscaled: 0.3512 (0.3942)  loss_bbox_0_unscaled: 0.0440 (0.0515)  loss_giou_0_unscaled: 0.0768 (0.0987)  cardinality_error_0_unscaled: 2414.7500 (2501.5049)  loss_ce_enc_unscaled: 0.4107 (0.4294)  loss_bbox_enc_unscaled: 0.0762 (0.0768)  loss_giou_enc_unscaled: 0.1076 (0.1255)  cardinality_error_enc_unscaled: 3139.5000 (3144.1716)  time: 2.4402  data: 0.0049  max mem: 4650
# Epoch: [1]  [  60/1029]  eta: 0:44:01  lr: 0.000100  class_error: -0.00  loss: 2.2617 (2.6174)  loss_ce: 0.3244 (0.3468)  loss_bbox: 0.1562 (0.2311)  loss_giou: 0.1346 (0.1824)  loss_ce_0: 0.3495 (0.3890)  loss_bbox_0: 0.1525 (0.2393)  loss_giou_0: 0.1224 (0.1831)  loss_ce_enc: 0.4311 (0.4305)  loss_bbox_enc: 0.3248 (0.3739)  loss_giou_enc: 0.1939 (0.2414)  loss_ce_unscaled: 0.3244 (0.3468)  class_error_unscaled: 0.0000 (0.9207)  loss_bbox_unscaled: 0.0312 (0.0462)  loss_giou_unscaled: 0.0673 (0.0912)  cardinality_error_unscaled: 2656.5000 (2997.9467)  loss_ce_0_unscaled: 0.3495 (0.3890)  loss_bbox_0_unscaled: 0.0305 (0.0479)  loss_giou_0_unscaled: 0.0612 (0.0915)  cardinality_error_0_unscaled: 2047.7500 (2445.6352)  loss_ce_enc_unscaled: 0.4311 (0.4305)  loss_bbox_enc_unscaled: 0.0650 (0.0748)  loss_giou_enc_unscaled: 0.0969 (0.1207)  cardinality_error_enc_unscaled: 2859.5000 (3103.3975)  time: 2.6819  data: 0.0052  max mem: 4650
# Epoch: [1]  [  70/1029]  eta: 0:43:24  lr: 0.000100  class_error: 0.00  loss: 2.0762 (2.5372)  loss_ce: 0.3054 (0.3400)  loss_bbox: 0.1551 (0.2188)  loss_giou: 0.1346 (0.1744)  loss_ce_0: 0.3220 (0.3815)  loss_bbox_0: 0.1463 (0.2269)  loss_giou_0: 0.1241 (0.1752)  loss_ce_enc: 0.3962 (0.4264)  loss_bbox_enc: 0.2789 (0.3605)  loss_giou_enc: 0.1794 (0.2334)  loss_ce_unscaled: 0.3054 (0.3400)  class_error_unscaled: 0.0000 (0.8982)  loss_bbox_unscaled: 0.0310 (0.0438)  loss_giou_unscaled: 0.0673 (0.0872)  cardinality_error_unscaled: 2665.0000 (2987.4507)  loss_ce_0_unscaled: 0.3220 (0.3815)  loss_bbox_0_unscaled: 0.0293 (0.0454)  loss_giou_0_unscaled: 0.0620 (0.0876)  cardinality_error_0_unscaled: 2189.5000 (2427.5070)  loss_ce_enc_unscaled: 0.3962 (0.4264)  loss_bbox_enc_unscaled: 0.0558 (0.0721)  loss_giou_enc_unscaled: 0.0897 (0.1167)  cardinality_error_enc_unscaled: 2753.7500 (3084.4507)  time: 2.6872  data: 0.0055  max mem: 4650
# Epoch: [1]  [  80/1029]  eta: 0:42:46  lr: 0.000100  class_error: 0.00  loss: 2.0762 (2.5239)  loss_ce: 0.2863 (0.3352)  loss_bbox: 0.1608 (0.2169)  loss_giou: 0.1294 (0.1726)  loss_ce_0: 0.3397 (0.3788)  loss_bbox_0: 0.1662 (0.2244)  loss_giou_0: 0.1241 (0.1735)  loss_ce_enc: 0.3927 (0.4232)  loss_bbox_enc: 0.3034 (0.3648)  loss_giou_enc: 0.1794 (0.2345)  loss_ce_unscaled: 0.2863 (0.3352)  class_error_unscaled: 0.0000 (0.8009)  loss_bbox_unscaled: 0.0322 (0.0434)  loss_giou_unscaled: 0.0647 (0.0863)  cardinality_error_unscaled: 2665.0000 (2940.3549)  loss_ce_0_unscaled: 0.3397 (0.3788)  loss_bbox_0_unscaled: 0.0332 (0.0449)  loss_giou_0_unscaled: 0.0620 (0.0868)  cardinality_error_0_unscaled: 2290.2500 (2407.7716)  loss_ce_enc_unscaled: 0.3927 (0.4232)  loss_bbox_enc_unscaled: 0.0607 (0.0730)  loss_giou_enc_unscaled: 0.0897 (0.1173)  cardinality_error_enc_unscaled: 2739.0000 (3029.6759)  time: 2.6377  data: 0.0060  max mem: 4650
# Epoch: [1]  [  90/1029]  eta: 0:42:05  lr: 0.000100  class_error: 0.00  loss: 2.3467 (2.4953)  loss_ce: 0.3036 (0.3298)  loss_bbox: 0.1765 (0.2137)  loss_giou: 0.1778 (0.1717)  loss_ce_0: 0.3437 (0.3719)  loss_bbox_0: 0.1742 (0.2202)  loss_giou_0: 0.1859 (0.1727)  loss_ce_enc: 0.4007 (0.4196)  loss_bbox_enc: 0.3384 (0.3611)  loss_giou_enc: 0.2390 (0.2346)  loss_ce_unscaled: 0.3036 (0.3298)  class_error_unscaled: 0.0000 (0.7692)  loss_bbox_unscaled: 0.0353 (0.0427)  loss_giou_unscaled: 0.0889 (0.0859)  cardinality_error_unscaled: 2665.0000 (2934.3104)  loss_ce_0_unscaled: 0.3437 (0.3719)  loss_bbox_0_unscaled: 0.0348 (0.0440)  loss_giou_0_unscaled: 0.0929 (0.0864)  cardinality_error_0_unscaled: 2334.0000 (2414.2088)  loss_ce_enc_unscaled: 0.4007 (0.4196)  loss_bbox_enc_unscaled: 0.0677 (0.0722)  loss_giou_enc_unscaled: 0.1195 (0.1173)  cardinality_error_enc_unscaled: 2706.2500 (3016.0687)  time: 2.5927  data: 0.0071  max mem: 4650
# Epoch: [1]  [ 100/1029]  eta: 0:41:32  lr: 0.000100  class_error: 0.96  loss: 2.2243 (2.4489)  loss_ce: 0.2627 (0.3230)  loss_bbox: 0.1647 (0.2089)  loss_giou: 0.1495 (0.1687)  loss_ce_0: 0.3104 (0.3638)  loss_bbox_0: 0.1516 (0.2146)  loss_giou_0: 0.1534 (0.1686)  loss_ce_enc: 0.3413 (0.4125)  loss_bbox_enc: 0.3005 (0.3564)  loss_giou_enc: 0.2139 (0.2324)  loss_ce_unscaled: 0.2627 (0.3230)  class_error_unscaled: 0.0000 (0.7026)  loss_bbox_unscaled: 0.0329 (0.0418)  loss_giou_unscaled: 0.0748 (0.0843)  cardinality_error_unscaled: 2644.5000 (2906.1906)  loss_ce_0_unscaled: 0.3104 (0.3638)  loss_bbox_0_unscaled: 0.0303 (0.0429)  loss_giou_0_unscaled: 0.0767 (0.0843)  cardinality_error_0_unscaled: 2307.0000 (2415.8639)  loss_ce_enc_unscaled: 0.3413 (0.4125)  loss_bbox_enc_unscaled: 0.0601 (0.0713)  loss_giou_enc_unscaled: 0.1070 (0.1162)  cardinality_error_enc_unscaled: 2706.2500 (2976.3886)  time: 2.5983  data: 0.0075  max mem: 4650
# Epoch: [1]  [ 110/1029]  eta: 0:40:45  lr: 0.000100  class_error: -0.00  loss: 2.1337 (2.4257)  loss_ce: 0.2587 (0.3192)  loss_bbox: 0.1561 (0.2054)  loss_giou: 0.1592 (0.1685)  loss_ce_0: 0.2810 (0.3614)  loss_bbox_0: 0.1559 (0.2113)  loss_giou_0: 0.1537 (0.1685)  loss_ce_enc: 0.3380 (0.4083)  loss_bbox_enc: 0.2892 (0.3510)  loss_giou_enc: 0.2175 (0.2320)  loss_ce_unscaled: 0.2587 (0.3192)  class_error_unscaled: 0.0000 (0.7016)  loss_bbox_unscaled: 0.0312 (0.0411)  loss_giou_unscaled: 0.0796 (0.0842)  cardinality_error_unscaled: 2636.7500 (2893.0270)  loss_ce_0_unscaled: 0.2810 (0.3614)  loss_bbox_0_unscaled: 0.0312 (0.0423)  loss_giou_0_unscaled: 0.0769 (0.0843)  cardinality_error_0_unscaled: 2307.0000 (2409.9279)  loss_ce_enc_unscaled: 0.3380 (0.4083)  loss_bbox_enc_unscaled: 0.0578 (0.0702)  loss_giou_enc_unscaled: 0.1087 (0.1160)  cardinality_error_enc_unscaled: 2703.7500 (2964.0586)  time: 2.5321  data: 0.0071  max mem: 4650
# Epoch: [1]  [ 120/1029]  eta: 0:40:20  lr: 0.000100  class_error: 0.00  loss: 2.1325 (2.4009)  loss_ce: 0.2713 (0.3171)  loss_bbox: 0.1561 (0.2023)  loss_giou: 0.1707 (0.1676)  loss_ce_0: 0.3107 (0.3583)  loss_bbox_0: 0.1625 (0.2075)  loss_giou_0: 0.1694 (0.1676)  loss_ce_enc: 0.3663 (0.4050)  loss_bbox_enc: 0.2711 (0.3453)  loss_giou_enc: 0.2273 (0.2301)  loss_ce_unscaled: 0.2713 (0.3171)  class_error_unscaled: 0.0000 (0.6437)  loss_bbox_unscaled: 0.0312 (0.0405)  loss_giou_unscaled: 0.0853 (0.0838)  cardinality_error_unscaled: 2667.2500 (2865.6632)  loss_ce_0_unscaled: 0.3107 (0.3583)  loss_bbox_0_unscaled: 0.0325 (0.0415)  loss_giou_0_unscaled: 0.0847 (0.0838)  cardinality_error_0_unscaled: 2153.7500 (2379.2789)  loss_ce_enc_unscaled: 0.3663 (0.4050)  loss_bbox_enc_unscaled: 0.0542 (0.0691)  loss_giou_enc_unscaled: 0.1136 (0.1151)  cardinality_error_enc_unscaled: 2703.7500 (2929.2913)  time: 2.5621  data: 0.0077  max mem: 4650

# %% [markdown]
# ## **Step 3: 推論テスト（トレーニング後に実行）**
#
# トレーニング完了後、または途中のチェックポイントを使用して推論をテストします。
#
# ⚠️ **トレーニングをまだ行っていない場合は、Step 4（トレーニング再開）を先に実行してください。**
#
# Cell 15でチェックポイントのパス（`CHECKPOINT_PATH`）を指定してください。

# %%
# 学習済みモデルのロードと推論（このセルを実行するだけでOK）

import os
import cv2
import torch
import matplotlib.pyplot as plt
from PIL import Image
from rfdetr import RFDETRNano

# ===== 設定 =====
# 4クラスモデルのチェックポイント（トレーニング後に適切なパスを指定）
CHECKPOINT_PATH = r'C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr_4class\checkpoint_best_total.pth'
TEST_IMAGE_PATH = r'C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2431\images\IMG_2431_0765.jpg'

# 4クラス定義（Lensを追加）
CLASSES = ['Lens', 'Fundus', 'Disc', 'Macula']
THRESHOLD = 0.5

# チェックポイントの確認
print(f"Checkpoint: {CHECKPOINT_PATH}")
print(f"Exists: {os.path.exists(CHECKPOINT_PATH)}")
print(f"Test Image: {TEST_IMAGE_PATH}")
print(f"Exists: {os.path.exists(TEST_IMAGE_PATH)}")
print(f"Classes: {CLASSES}")

# モデルのロード
model = RFDETRNano(pretrain_weights=CHECKPOINT_PATH)
print("\nModel loaded successfully!")

# 推論実行
print(f"\n=== Running Inference (threshold={THRESHOLD}) ===")
detections = model.predict(TEST_IMAGE_PATH, threshold=THRESHOLD)

# 結果の表示（detectionsの形式を確認）
print(f"\nDetection object type: {type(detections)}")
print(f"Detection object: {detections}")

# supervision.Detectionsオブジェクトかどうか確認
# supervision.Detectionsはxyxy, confidence, class_id属性を持つ
parsed_detections = []

if hasattr(detections, 'xyxy') and hasattr(detections, 'confidence') and hasattr(detections, 'class_id'):
    # supervision.Detections形式
    print(f"\n=== supervision.Detections format detected ===")
    print(f"Number of detections: {len(detections.xyxy)}")
    
    for i in range(len(detections.xyxy)):
        bbox = detections.xyxy[i].tolist()  # [x1, y1, x2, y2]
        conf = float(detections.confidence[i]) if detections.confidence is not None else 0.0
        class_id = int(detections.class_id[i]) if detections.class_id is not None else 0
        class_name = CLASSES[class_id] if class_id < len(CLASSES) else f"class_{class_id}"
        
        parsed_detections.append({
            'class_id': class_id,
            'class_name': class_name,
            'confidence': conf,
            'bbox': bbox
        })
        print(f"  [{i+1}] Class: {class_name}, Confidence: {conf:.4f}, BBox: {bbox}")
else:
    # その他の形式（リストやdict）
    print(f"\n=== Other format ===")
    for i, det in enumerate(detections):
        print(f"  Detection {i}: type={type(det)}, value={det}")

print(f"\nTotal parsed detections: {len(parsed_detections)}")

# %%
# 検出結果の可視化（マスク描画版）

import cv2
import matplotlib.pyplot as plt
import numpy as np

# 画像読み込み
img = cv2.imread(TEST_IMAGE_PATH)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_overlay = img.copy()

# カラーマップ（4クラス対応）- RGB形式
# Lens: Yellow, Fundus: Red, Disc: Green, Macula: Blue
colors = [
    (255, 255, 0),  # Lens: Yellow
    (255, 0, 0),    # Fundus: Red
    (0, 255, 0),    # Disc: Green
    (0, 0, 255),    # Macula: Blue
]

# マスク画像を作成
mask_overlay = np.zeros_like(img)

# 検出結果を画像に描画（マスクとしてマージ）
for det in parsed_detections:
    class_id = det['class_id']
    class_name = det['class_name']
    conf = det['confidence']
    bbox = det['bbox']
    color = colors[class_id % len(colors)]
    
    if len(bbox) >= 4:
        x1, y1, x2, y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
        
        # bboxから楕円マスクを作成（眼底・視神経乳頭・黄斑は楕円形に近い）
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2
        axes_x = (x2 - x1) // 2
        axes_y = (y2 - y1) // 2
        
        # マスクオーバーレイに楕円を描画（塗りつぶし）
        cv2.ellipse(mask_overlay, (center_x, center_y), (axes_x, axes_y), 0, 0, 360, color, -1)
        
        # 境界線（楕円の輪郭）
        cv2.ellipse(img_overlay, (center_x, center_y), (axes_x, axes_y), 0, 0, 360, color, 3)
        
        # ラベル描画
        label = f"{class_name}: {conf:.2f}"
        label_size, _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2)
        cv2.rectangle(img_overlay, (x1, y1 - label_size[1] - 10), (x1 + label_size[0], y1), color, -1)
        cv2.putText(img_overlay, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

# マスクを元画像に半透明でオーバーレイ
alpha = 0.4
result = cv2.addWeighted(img_overlay, 1, mask_overlay, alpha, 0)

# 画像表示
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].imshow(img)
axes[0].set_title('Original Image')
axes[0].axis('off')

axes[1].imshow(mask_overlay)
axes[1].set_title('Mask Overlay')
axes[1].axis('off')

axes[2].imshow(result)
axes[2].set_title(f'Detection with Mask ({len(parsed_detections)} objects)')
axes[2].axis('off')

plt.tight_layout()
plt.show()

# 結果を保存
output_path = r'C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr\inference_result_mask.jpg'
cv2.imwrite(output_path, cv2.cvtColor(result, cv2.COLOR_RGB2BGR))
print(f"\nResult saved to: {output_path}")

# %% [markdown]
# ### **【参考】旧パイプライン: RT-DETR（Lens検出）→ 円形切り抜き → RF-DETR（Fundus/Disc/Macula検出）**
#
# ⚠️ **注意**: このセクションは**旧パイプライン**の参考コードです。
#
# **新しいアプローチ（このノートブック）:**
# - RF-DETR単体で4クラス（Lens, Fundus, Disc, Macula）を同時検出
#
# **旧アプローチ（以下のコード）:**
# 1. **RT-DETR** でLens（レンズ）を検出
# 2. Lens領域をクロップし、円形マスクを適用
# 3. **RF-DETR** でFundus/Disc/Maculaを検出
#
# 旧パイプラインを使用する場合は、別途RT-DETRモデル（Lens検出用）が必要です。

# %%
# 【参考】旧パイプライン: RT-DETR（Lens検出）→ 円形切り抜き → RF-DETR（Fundus/Disc/Macula検出）
# 
# ⚠️ このコードは旧パイプラインの参考用です。
# 新しいアプローチでは、RF-DETR単体で4クラス（Lens, Fundus, Disc, Macula）を検出します。

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from rfdetr import RFDETRNano
from ultralytics import RTDETR
from tqdm import tqdm

# ===== 設定 =====
# RT-DETRモデル（Lens検出用）- 旧パイプライン用
RTDETR_MODEL_PATH = r'C:\Users\ykita\ROP_AI_project\ROP_project\models\rtdetr-l-1697_1703.pt'

# RF-DETRモデル（Fundus/Disc/Macula検出用）- 旧パイプライン用（3クラスモデル）
RFDETR_CHECKPOINT_PATH = r'C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr\checkpoint0043.pth'

# テスト画像
TEST_IMAGE_PATH = r'C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2431\images\IMG_2431_0765.jpg'

# パラメータ
GRAY_VALUE = (114, 114, 114)
THRESHOLD = 0.5

# 4クラス定義（新しいアプローチ用）
# 旧パイプラインでは3クラス（Fundus, Disc, Macula）のみ使用
CLASSES_NEW = ['Lens', 'Fundus', 'Disc', 'Macula']  # 新しいアプローチ
CLASSES_OLD = ['Fundus', 'Disc', 'Macula']  # 旧パイプライン

# このセルでは旧パイプラインを使用するためCLASSES_OLDを使用
CLASSES = CLASSES_OLD

# ===== モデルロード =====
print("Loading RT-DETR (Lens detection)...")
rtdetr_model = RTDETR(RTDETR_MODEL_PATH)
print("Loading RF-DETR (Fundus/Disc/Macula detection)...")
rfdetr_model = RFDETRNano(pretrain_weights=RFDETR_CHECKPOINT_PATH)
print("Models loaded!")


def detect_lens_rtdetr(model, image):
    """RT-DETRでLens (cls=0) を検出"""
    results = model(image, verbose=False)
    lens_bbox = None
    
    for r in results:
        if r.boxes is None or len(r.boxes) == 0:
            continue
        for box in r.boxes:
            if int(box.cls) == 0:  # Lens
                lens_bbox = box.xyxy[0].cpu().numpy()
                break
        if lens_bbox is not None:
            break
    
    return lens_bbox


def apply_circular_mask(cropped_image, gray_value=(114, 114, 114)):
    """クロップ画像に円形マスクを適用（Lens外を灰色に）"""
    h, w = cropped_image.shape[:2]
    center_x = w // 2
    center_y = h // 2
    diameter = (w + h) / 2
    radius = int(diameter / 2)
    
    # 円形マスク作成
    circle_mask = np.zeros((h, w), dtype=np.uint8)
    cv2.circle(circle_mask, (center_x, center_y), radius, 255, -1)
    
    # マスク適用
    masked = cropped_image.copy()
    masked[circle_mask == 0] = gray_value
    
    return masked, circle_mask, (center_x, center_y, radius)


def detect_fundus_rfdetr(model, image_or_path, threshold=0.5):
    """RF-DETRでFundus/Disc/Maculaを検出"""
    detections = model.predict(image_or_path, threshold=threshold)
    
    parsed = []
    if hasattr(detections, 'xyxy') and hasattr(detections, 'class_id'):
        for i in range(len(detections.xyxy)):
            bbox = detections.xyxy[i].tolist()
            conf = float(detections.confidence[i]) if detections.confidence is not None else 0.0
            class_id = int(detections.class_id[i]) if detections.class_id is not None else 0
            class_name = CLASSES[class_id] if class_id < len(CLASSES) else f"class_{class_id}"
            parsed.append({
                'class_id': class_id,
                'class_name': class_name,
                'confidence': conf,
                'bbox': bbox
            })
    
    return parsed


def process_pipeline(rtdetr_model, rfdetr_model, image_path, threshold=0.5, gray_value=(114, 114, 114)):
    """
    旧パイプライン：
    1. RT-DETRでLens検出
    2. Lens領域をクロップ + 円形マスク
    3. RF-DETRでFundus/Disc/Macula検出
    """
    # 画像読み込み
    image = cv2.imread(image_path)
    if image is None:
        return None
    
    result = {
        'image_path': image_path,
        'original_image': image.copy(),
        'lens_detected': False,
        'lens_bbox': None,
        'cropped_image': None,
        'masked_image': None,
        'mask_info': None,
        'detections': []
    }
    
    # Stage 1: RT-DETRでLens検出
    lens_bbox = detect_lens_rtdetr(rtdetr_model, image)
    
    if lens_bbox is None:
        print(f"  Warning: Lens not detected in {os.path.basename(image_path)}")
        return result
    
    result['lens_detected'] = True
    result['lens_bbox'] = lens_bbox
    
    # Lens領域をクロップ
    x1, y1, x2, y2 = [int(c) for c in lens_bbox]
    cropped = image[y1:y2, x1:x2]
    
    if cropped.size == 0:
        print(f"  Warning: Empty crop in {os.path.basename(image_path)}")
        return result
    
    result['cropped_image'] = cropped.copy()
    
    # Stage 2: 円形マスク適用
    masked, circle_mask, mask_info = apply_circular_mask(cropped, gray_value)
    result['masked_image'] = masked
    result['mask_info'] = mask_info
    
    # 一時ファイルに保存してRF-DETRで推論
    temp_path = os.path.join(os.path.dirname(image_path), '_temp_masked.jpg')
    cv2.imwrite(temp_path, masked)
    
    # Stage 3: RF-DETRでFundus/Disc/Macula検出
    detections = detect_fundus_rfdetr(rfdetr_model, temp_path, threshold)
    result['detections'] = detections
    
    # 一時ファイル削除
    if os.path.exists(temp_path):
        os.remove(temp_path)
    
    return result


# ===== テスト実行 =====
print(f"\n=== Processing: {TEST_IMAGE_PATH} ===")
result = process_pipeline(rtdetr_model, rfdetr_model, TEST_IMAGE_PATH, threshold=THRESHOLD)

if result and result['lens_detected']:
    print(f"  Lens detected: {result['lens_bbox']}")
    print(f"  Mask info: center=({result['mask_info'][0]}, {result['mask_info'][1]}), radius={result['mask_info'][2]}")
    print(f"\n  Detections ({len(result['detections'])}):")
    for det in result['detections']:
        print(f"    - {det['class_name']}: {det['confidence']:.4f}, bbox={det['bbox']}")
else:
    print("  Lens not detected - pipeline failed")

# %%
# 【参考】旧パイプライン結果の可視化（マスク描画版）

if result and result['lens_detected']:
    # 画像を準備
    original_rgb = cv2.cvtColor(result['original_image'], cv2.COLOR_BGR2RGB)
    cropped_rgb = cv2.cvtColor(result['cropped_image'], cv2.COLOR_BGR2RGB)
    masked_rgb = cv2.cvtColor(result['masked_image'], cv2.COLOR_BGR2RGB)
    
    # 検出結果をマスクで描画
    result_img = masked_rgb.copy()
    mask_overlay = np.zeros_like(masked_rgb)
    
    # カラーマップ（4クラス対応）
    # 旧パイプラインでは3クラスのみ使用（Fundus: Red, Disc: Green, Macula: Blue）
    colors = [
        (255, 255, 0),  # Lens: Yellow（新パイプライン用）
        (255, 0, 0),    # Fundus: Red
        (0, 255, 0),    # Disc: Green
        (0, 0, 255),    # Macula: Blue
    ]
    
    for det in result['detections']:
        class_id = det['class_id']
        class_name = det['class_name']
        conf = det['confidence']
        bbox = det['bbox']
        # 旧パイプラインではclass_idが0から始まるので、+1してcolorsにマッピング
        color = colors[(class_id + 1) % len(colors)]
        
        x1, y1, x2, y2 = [int(v) for v in bbox]
        
        # bboxから楕円マスクを作成
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2
        axes_x = (x2 - x1) // 2
        axes_y = (y2 - y1) // 2
        
        # マスクオーバーレイに楕円を描画（塗りつぶし）
        cv2.ellipse(mask_overlay, (center_x, center_y), (axes_x, axes_y), 0, 0, 360, color, -1)
        
        # 境界線（楕円の輪郭）
        cv2.ellipse(result_img, (center_x, center_y), (axes_x, axes_y), 0, 0, 360, color, 3)
        
        # ラベル描画
        label = f"{class_name}: {conf:.2f}"
        label_size, _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2)
        cv2.rectangle(result_img, (x1, y1 - label_size[1] - 10), (x1 + label_size[0], y1), color, -1)
        cv2.putText(result_img, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    
    # マスクを半透明でオーバーレイ
    alpha = 0.4
    result_with_mask = cv2.addWeighted(result_img, 1, mask_overlay, alpha, 0)
    
    # 4つの画像を表示
    fig, axes = plt.subplots(2, 2, figsize=(14, 14))
    
    # 1. 元画像
    axes[0, 0].imshow(original_rgb)
    axes[0, 0].set_title('1. Original Image')
    axes[0, 0].axis('off')
    
    # 2. Lens領域クロップ
    axes[0, 1].imshow(cropped_rgb)
    axes[0, 1].set_title('2. Lens Cropped (RT-DETR)')
    axes[0, 1].axis('off')
    
    # 3. 円形マスク適用
    axes[1, 0].imshow(masked_rgb)
    axes[1, 0].set_title('3. Circular Mask Applied')
    axes[1, 0].axis('off')
    
    # 4. RF-DETR検出結果（マスク表示）
    axes[1, 1].imshow(result_with_mask)
    axes[1, 1].set_title(f'4. RF-DETR Detection - Mask ({len(result["detections"])} objects)')
    axes[1, 1].axis('off')
    
    plt.tight_layout()
    plt.show()
    
    # 保存
    output_path = r'C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr\pipeline_result_mask.jpg'
    cv2.imwrite(output_path, cv2.cvtColor(result_with_mask, cv2.COLOR_RGB2BGR))
    print(f"\nResult saved to: {output_path}")
else:
    print("No result to visualize - Lens not detected")

# %%
# 【オプション】複数画像での推論（別の画像でテストしたい場合）

import os
import glob

def run_inference_on_image(model, image_path, classes, threshold=0.5):
    """単一画像に対して推論を実行し可視化"""
    # 推論
    detections = model.predict(image_path, threshold=threshold)
    
    # 画像読み込み
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # カラーマップ（4クラス対応）
    colors = [
        (255, 255, 0),  # Lens: Yellow
        (255, 0, 0),    # Fundus: Red
        (0, 255, 0),    # Disc: Green
        (0, 0, 255),    # Macula: Blue
    ]
    
    for det in detections:
        class_id = det.get('class_id', det.get('class', 0))
        class_name = classes[class_id] if isinstance(class_id, int) and class_id < len(classes) else str(class_id)
        conf = det.get('confidence', det.get('score', 0))
        bbox = det.get('bbox', det.get('box', []))
        color = colors[class_id % len(colors)] if isinstance(class_id, int) else (255, 255, 0)
        
        if len(bbox) >= 4:
            x1, y1 = int(bbox[0]), int(bbox[1])
            x2, y2 = int(bbox[2]), int(bbox[3])
            cv2.rectangle(img, (x1, y1), (x2, y2), color, 3)
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
    
    return img, detections

# 別の画像でテスト（パスを変更して実行）
# CLASSES = ['Lens', 'Fundus', 'Disc', 'Macula']  # 4クラス
# test_images = [
#     r'C:\Users\ykita\ROP_AI_project\ROP_project\data\ROP_image\IMG_2025\IMG_2025_0001.jpg',
#     r'C:\Users\ykita\ROP_AI_project\ROP_project\data\ROP_image\IMG_2025\IMG_2025_0002.jpg',
# ]
# 
# for img_path in test_images:
#     if os.path.exists(img_path):
#         img, dets = run_inference_on_image(model, img_path, CLASSES, threshold=0.5)
#         plt.figure(figsize=(12, 8))
#         plt.imshow(img)
#         plt.title(os.path.basename(img_path))
#         plt.axis('off')
#         plt.show()

# %% [markdown]
# ## **Step 4: トレーニング済みモデルの保存と再開**

# %%
# トレーニングの再開（このセルを実行するだけでOK）

import os
from rfdetr import RFDETRNano

# ===== 設定 =====
COCO_DATA_DIR = r'C:\Users\ykita\ROP_AI_project\ROP_project\data\train_coco'
OUTPUT_DIR = r'C:\Users\ykita\ROP_AI_project\ROP_project\runs\rfdetr_4class'

EPOCHS = 100
BATCH_SIZE = 4
LEARNING_RATE = 1e-4
LEARNING_RATE_ENCODER = 1.5e-4
WEIGHT_DECAY = 1e-4
RESOLUTION = 448

# ===== チェックポイント選択 =====
# 以下から1つ選んでコメントを外してください：
CHECKPOINT_TYPE = "latest"       # 最新のチェックポイント（中断した場所から再開）
# CHECKPOINT_TYPE = "best_ema"   # EMAモデルのベスト
# CHECKPOINT_TYPE = "best_regular"  # 通常モデルのベスト
# CHECKPOINT_TYPE = "best_total"    # 総合ベスト

checkpoint_files = {
    "latest": "checkpoint.pth",
    "best_ema": "checkpoint_best_ema.pth",
    "best_regular": "checkpoint_best_regular.pth",
    "best_total": "checkpoint_best_total.pth"
}
checkpoint_path = os.path.join(OUTPUT_DIR, checkpoint_files[CHECKPOINT_TYPE])

print(f"Checkpoint type: {CHECKPOINT_TYPE}")
print(f"Resuming from: {checkpoint_path}")
print(f"Checkpoint exists: {os.path.exists(checkpoint_path)}")

# モデル作成とトレーニング再開
model = RFDETRNano()
model.train(
    dataset_dir=COCO_DATA_DIR,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    grad_accum_steps=4,
    lr=LEARNING_RATE,
    lr_encoder=LEARNING_RATE_ENCODER,
    weight_decay=WEIGHT_DECAY,
    resolution=RESOLUTION,
    use_ema=True,
    checkpoint_interval=1,
    early_stopping=True,
    early_stopping_patience=20,
    resume=checkpoint_path,
    device="cuda",
    output_dir=OUTPUT_DIR
)

# %% [markdown]
# ## **補足: RF-DETR モデルバリアント**
#
# RF-DETRには以下のモデルバリアントがあります：
#
# | Model | Parameters | COCO mAP | Speed |
# |-------|------------|----------|-------|
# | RF-DETR-N (Nano) | ~5M | ~40 | Fastest |
# | RF-DETR-B (Base) | ~29M | ~53 | Fast |
# | RF-DETR-L (Large) | ~128M | ~56 | Moderate |
#
# 他のバリアントを使用する場合：
#
# ```python
# from rfdetr import RFDETRBase, RFDETRLarge
#
# model = RFDETRBase()  # Base model
# model = RFDETRLarge()  # Large model
# ```

# %%
# モデルのエクスポート（ONNX形式）
# 
# export_path = os.path.join(OUTPUT_DIR, 'rf_detr_nano.onnx')
# model.export(export_path, format='onnx')
# print(f"Model exported to {export_path}")
