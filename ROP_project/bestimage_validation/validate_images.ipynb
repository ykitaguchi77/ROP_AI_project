# %% [markdown]
# # validate_images.ipynb
#
# このノートブックは、**画像フォルダ**と**モデル（RT-DETR検出 / YOLO-seg）**を指定すると、
#
# - 各画像の推論（Lens検出 → Lens内でRetina/Disc/Maculaセグメンテーション）
# - 画像品質スコア（MBSS系 + Disc周辺）算出
# - **Best画像抽出**
#
# までを実行します。
#
# ## セル構成
#
# | # | 種類 | 内容 |
# |---|------|------|
# | 0 | markdown | 概要説明（このセル） |
# | 1 | code | パラメータ設定（単一ケース用） |
# | 2 | code | MBSS関数定義 |
# | 3 | code | process_one_image関数定義 |
# | 4 | markdown | 推論実行（単一ケース）の説明 |
# | 5 | code | **推論実行（単一ケース）** |
# | 6 | markdown | バッチ推論の説明 |
# | 7 | code | **バッチ推論：ケース検索** |
# | 8 | code | **バッチ推論：実行** |
# | 9 | markdown | Best画像選定（単一ケース）の説明 |
# | 10 | code | **Best画像選定（単一ケース）** |
# | 11 | markdown | Best画像選定（バッチ）の説明 |
# | 12 | code | **Best画像選定（バッチ）** |
#
# ### 使い方
# - **単一ケース**: 2 → 3 → 5 → 10
# - **複数ケース**: 2 → 3 → 7 → 8 → 12
#
# ## Best画像選定アルゴリズム
#
# ### 方針
# 1. **disc_pos_ok=True** の画像を優先的に抽出（Discが中心から25-75%の位置）
# 2. **retina_area** でベースランキング（大きいほど上位）
# 3. 品質指標でボーナス加算
# 4. 画像が足りなければ **disc_pos_ok=False** から補完
#
# ### ランキング計算
#
# ```
# rank_sum = 1.5 × retina_area_rank + 1.0 × mbss_rank + 0.5 × disc_ring_rank + 0.5 × s_mean_rank
# ```
#
# （小さいほど上位）
#
# ### Stage構成
#
# | Stage | 対象 | 説明 |
# |-------|------|------|
# | Stage 1 | disc_pos_ok=True | Disc位置が良い画像を優先 |
# | Stage 2 | disc_pos_ok=False | 不足分を補完 |
#
# ### 品質指標
#
# | 指標 | 説明 | 重み |
# |------|------|------|
# | retina_area | 網膜検出面積（大きいほど良い） | 1.5 |
# | mbss_score | ピント品質スコア | 1.0 |
# | disc_ring_score | Disc周辺のピント | 0.5 |
# | S_mean | 彩度（コントラスト） | 0.5 |
#
# > 想定入力: `bestimage_validation/*/images/` フォルダ（*は患者番号）

# %%
import os
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
from ultralytics import RTDETR, YOLO

# -------------------- 入力パラメータ（ここだけ変更すればOK） --------------------

# 画像フォルダ（jpg/png等が入ったフォルダ）
image_dir = r"C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1227\images"
# モデルパス
rtdetr_model_path = r"C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\models\\rtdetr-l-1697_1703.pt"
yolo_seg_model_path = r"C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\models\\yolo11n-seg_19movies.pt"

# 出力先（CSV / xlsx）
# - per-caseのCSVは `bestimage_validation/validation_results/` に保存（集計側と合わせる）
# - per-caseのBest画像Excelは `bestimage_validation/` に保存（任意）
output_root = r"C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\bestimage_validation"

# Best候補数
top_k = 10   # 最終出力（Top10）
need_k = 5   # 研究用途で最低必要（Top5）

# 画像拡張子
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')

# YOLO入力幅（ノートブック内で固定）
YOLO_INPUT_WIDTH = 640

# -----------------------------------------------------------------------------

case_id = Path(image_dir).parent.name  # 例: ...\1227\画像 -> 1227
output_root = Path(output_root)
output_root.mkdir(parents=True, exist_ok=True)

# CSVは専用フォルダへ
validation_results_dir = output_root / "validation_results"
validation_results_dir.mkdir(parents=True, exist_ok=True)

output_csv_path = validation_results_dir / f"validation_results_{case_id}.csv"
output_best_xlsx_path = output_root / f"best_images_{case_id}.xlsx"

print("case_id:", case_id)
print("image_dir:", image_dir)
print("output_csv_path:", output_csv_path)
print("output_best_xlsx_path:", output_best_xlsx_path)
# Out:
# case_id: 1227
# image_dir: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1227\images
# output_csv_path: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1227.csv
# output_best_xlsx_path: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\best_images_1227.xlsx

# %%
# ==================== 画像品質特徴量（MBSS） ====================

def to_gray_float(img_bgr_or_gray: np.ndarray) -> np.ndarray:
    """BGR/Gray いずれも float32 [0,1] グレースケールへ"""
    if img_bgr_or_gray.ndim == 3:
        gray = cv2.cvtColor(img_bgr_or_gray, cv2.COLOR_BGR2GRAY)
    else:
        gray = img_bgr_or_gray
    gray = gray.astype(np.float32)
    if gray.max() > 1.0:
        gray /= 255.0
    return gray


def laplacian_multi_var(gray01: np.ndarray, sigmas=(1.0, 2.0, 4.0), weights=(0.5, 0.3, 0.2)) -> float:
    """マルチスケール Laplacian 分散（重み付き和）"""
    vals = []
    for s, w in zip(sigmas, weights):
        ksize = int(6 * s + 1)
        if ksize % 2 == 0:
            ksize += 1
        blur = cv2.GaussianBlur(gray01, (ksize, ksize), s)
        lap = cv2.Laplacian(blur, cv2.CV_32F, ksize=3)
        vals.append(w * float(lap.var()))
    return float(np.sum(vals))


def fft_features(gray01: np.ndarray, high_freq_thresh=0.3) -> tuple:
    """FFT高周波エネルギー比とスペクトル重心（NumPy FFT版）"""
    h, w = gray01.shape

    wy = np.hanning(h).astype(np.float32)
    wx = np.hanning(w).astype(np.float32)
    window = np.outer(wy, wx)
    g = gray01 * window

    F = np.fft.fftshift(np.fft.fft2(g))
    mag2 = (np.abs(F) ** 2).astype(np.float64)

    cy, cx = h // 2, w // 2
    yy, xx = np.indices((h, w))
    ry = (yy - cy) / float(max(cy, 1))
    rx = (xx - cx) / float(max(cx, 1))
    r = np.sqrt(rx ** 2 + ry ** 2)
    r_norm = np.clip(r, 0, 1)

    total = mag2.sum() + 1e-12
    high_mask = r_norm > high_freq_thresh
    hf_ratio = float(mag2[high_mask].sum() / total)
    spec_centroid = float((r_norm * mag2).sum() / total)
    return hf_ratio, spec_centroid


from typing import Optional, Dict, Any


def grad_percentile(gray01: np.ndarray, p=90) -> float:
    gx = cv2.Sobel(gray01, cv2.CV_32F, 1, 0, ksize=3)
    gy = cv2.Sobel(gray01, cv2.CV_32F, 0, 1, ksize=3)
    mag = np.sqrt(gx ** 2 + gy ** 2)
    return float(np.percentile(mag, p))


def compute_mbss_components(img_bgr: np.ndarray, mask01: Optional[np.ndarray] = None) -> Dict[str, Any]:
    """Retina領域（mask）内のみで MBSS コンポーネントを算出

    NOTE:
    - 既存のMBSS系（Laplacian/FFT/Grad）はマスク外を0にして計算
    - 色調用に、網膜マスク内の彩度平均 `S_mean`（HSVのS）も同時に返す
    """
    gray = to_gray_float(img_bgr)

    mask_bool = None
    if mask01 is not None:
        if mask01.shape != gray.shape:
            mask01 = cv2.resize(mask01.astype(np.uint8), (gray.shape[1], gray.shape[0]), interpolation=cv2.INTER_NEAREST)
        mask_bool = mask01 > 0
        if mask_bool.sum() < 100:
            return {"L_multi": None, "HF_ratio": None, "Spec_centroid": None, "Grad_p90": None, "S_mean": None}
        gray2 = gray.copy()
        gray2[~mask_bool] = 0.0
    else:
        gray2 = gray

    # --- 色調（HSV彩度Sの平均、網膜マスク内） ---
    s_mean = None
    if mask_bool is not None and img_bgr is not None and getattr(img_bgr, "ndim", 0) == 3:
        hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
        s = hsv[:, :, 1].astype(np.float32)
        if s.max() > 1.0:
            s /= 255.0
        roi = s[mask_bool]
        if roi.size > 0:
            s_mean = float(np.mean(roi))

    return {
        "L_multi": laplacian_multi_var(gray2),
        "HF_ratio": fft_features(gray2)[0],
        "Spec_centroid": fft_features(gray2)[1],
        "Grad_p90": grad_percentile(gray2),
        "S_mean": s_mean,
    }


def compute_mbss_score(components: dict, stats: dict, weights=None) -> Optional[float]:
    """z-score正規化後、重み付き和でスコア化"""
    if any(components.get(k) is None for k in ["L_multi", "HF_ratio", "Spec_centroid", "Grad_p90"]):
        return None

    if weights is None:
        weights = {"L_multi": 0.35, "HF_ratio": 0.25, "Spec_centroid": 0.20, "Grad_p90": 0.20}

    score = 0.0
    for k, w in weights.items():
        x = float(components[k])
        m = float(stats[k]["mean"])
        s = float(stats[k]["std"]) + 1e-8
        z = (x - m) / s
        score += w * z
    return float(score)


# ==================== Disc周囲（core/ring）評価 ====================

def estimate_disc_center_radius(disc_mask01: np.ndarray):
    """discマスクから中心(cx,cy)と代表半径Rを推定"""
    m = disc_mask01.astype(np.uint8)
    if m.max() > 1:
        m = (m > 0).astype(np.uint8)

    num_labels, labels = cv2.connectedComponents(m)
    if num_labels > 1:
        areas = [(labels == i).sum() for i in range(1, num_labels)]
        main_label = int(np.argmax(areas) + 1)
        m = (labels == main_label).astype(np.uint8)

    M = cv2.moments(m)
    if M["m00"] == 0:
        return None

    cx = M["m10"] / M["m00"]
    cy = M["m01"] / M["m00"]
    area = float(m.sum())
    R = float(np.sqrt(area / np.pi))
    return cx, cy, R


def make_disc_rois(shape_hw, cx, cy, R, inner_ratio=0.6, outer_ratio=1.2):
    h, w = shape_hw
    yy, xx = np.indices((h, w))
    dist = np.sqrt((xx - cx) ** 2 + (yy - cy) ** 2)
    core = dist < (inner_ratio * R)
    ring = (dist >= (inner_ratio * R)) & (dist < (outer_ratio * R))
    return core.astype(np.uint8), ring.astype(np.uint8)


def laplacian_multi_var_masked(gray01: np.ndarray, mask01: np.ndarray, sigmas=(1.0, 2.0, 4.0), weights=(0.5, 0.3, 0.2)) -> float:
    mask_bool = mask01.astype(bool)
    if mask_bool.sum() < 50:
        return 0.0

    vals = []
    for s, w in zip(sigmas, weights):
        ksize = int(6 * s + 1)
        if ksize % 2 == 0:
            ksize += 1
        blur = cv2.GaussianBlur(gray01, (ksize, ksize), s)
        lap = cv2.Laplacian(blur, cv2.CV_32F, ksize=3)
        roi = lap[mask_bool]
        if roi.size == 0:
            continue
        vals.append(w * float(roi.var()))
    return float(np.sum(vals)) if vals else 0.0


def compute_disc_sharpness_components(img_bgr: np.ndarray, disc_mask01: np.ndarray):
    """disc中心(core)と周辺(ring)の L_multi を返す"""
    gray = to_gray_float(img_bgr)
    est = estimate_disc_center_radius(disc_mask01)
    if est is None:
        return None, None

    cx, cy, R = est
    core_mask, ring_mask = make_disc_rois(gray.shape, cx, cy, R)

    if core_mask.sum() < 50 or ring_mask.sum() < 50:
        return None, None

    L_core = laplacian_multi_var_masked(gray, core_mask)
    L_ring = laplacian_multi_var_masked(gray, ring_mask)
    return L_core, L_ring

# %%
from typing import Optional


def process_one_image(image_path: str, detection_model, segmentation_model) -> Optional[dict]:
    """1枚の画像に対して推論 + 特徴量を算出"""
    image = cv2.imread(image_path)
    if image is None:
        return None

    # --- Stage 1: RT-DETRでLens bbox検出（cls=0想定） ---
    det_results = detection_model(image, verbose=False)
    lens_bbox_xyxy = None
    for r in det_results:
        if r.boxes is None or len(r.boxes) == 0:
            continue
        for box in r.boxes:
            if int(box.cls) == 0:
                lens_bbox_xyxy = box.xyxy[0].cpu().numpy()
                break
        if lens_bbox_xyxy is not None:
            break

    if lens_bbox_xyxy is None:
        return {
            'image_path': image_path,
            'lens_detected': False,
            'lens_area': 0,
            'retina_area': 0,
            'retina_ratio': 0.0,
            'disc_detected': False,
            'macula_detected': False,
            'mbss_L_multi': None,
            'mbss_HF_ratio': None,
            'mbss_Spec_centroid': None,
            'mbss_Grad_p90': None,
            'S_mean': None,
            'disc_core_L_multi': None,
            'disc_ring_L_multi': None,
            'disc_center_dist_ratio': None,
            'disc_pos_ok': None,
        }

    x1, y1, x2, y2 = [int(c) for c in lens_bbox_xyxy]
    cropped = image[y1:y2, x1:x2]
    if cropped.size == 0:
        return {
            'image_path': image_path,
            'lens_detected': True,
            'lens_area': 0,
            'retina_area': 0,
            'retina_ratio': 0.0,
            'disc_detected': False,
            'macula_detected': False,
            'mbss_L_multi': None,
            'mbss_HF_ratio': None,
            'mbss_Spec_centroid': None,
            'mbss_Grad_p90': None,
            'S_mean': None,
            'disc_core_L_multi': None,
            'disc_ring_L_multi': None,
            'disc_center_dist_ratio': None,
            'disc_pos_ok': None,
        }

    # --- Lens内での円形マスク（レンズ外を灰色にする） ---
    orig_h, orig_w = cropped.shape[:2]
    center_x = orig_w // 2
    center_y = orig_h // 2
    diameter = (orig_w + orig_h) / 2
    radius = int(diameter / 2)

    circle_mask = np.zeros((orig_h, orig_w), dtype=np.uint8)
    cv2.circle(circle_mask, (center_x, center_y), radius, 255, -1)

    masked_cropped = cropped.copy()
    masked_cropped[circle_mask == 0] = (114, 114, 114)

    lens_area = int((circle_mask > 0).sum())

    # --- Stage 2: YOLO-seg ---
    aspect_ratio = orig_h / max(orig_w, 1)
    yolo_h = int(YOLO_INPUT_WIDTH * aspect_ratio)
    yolo_input = cv2.resize(masked_cropped, (YOLO_INPUT_WIDTH, yolo_h), interpolation=cv2.INTER_AREA)

    seg_results = segmentation_model(yolo_input, verbose=False, retina_masks=True)

    retina_area = 0
    disc_detected = False
    macula_detected = False

    retina_mask_crop = None
    disc_mask_crop = None

    if seg_results and seg_results[0].masks is not None:
        r0 = seg_results[0]
        masks = r0.masks.data.cpu().numpy()
        classes = r0.boxes.cls.cpu().numpy().astype(int)

        for mask_data, cls_id in zip(masks, classes):
            # mask_data: (H', W') 0..1
            mask_resized = cv2.resize(mask_data, (orig_w, orig_h), interpolation=cv2.INTER_LINEAR)
            mask_bin = (mask_resized > 0.5) & (circle_mask > 0)

            if cls_id == 0:  # Fundus/Retina
                retina_area = int(mask_bin.sum())
                retina_mask_crop = (mask_bin.astype(np.uint8) * 255)
            elif cls_id == 1:  # Disc
                disc_detected = True
                disc_mask_crop = (mask_bin.astype(np.uint8) * 255)
            elif cls_id == 2:  # Macula
                macula_detected = True

    retina_ratio = (retina_area / lens_area * 100.0) if lens_area > 0 else 0.0

    # --- MBSS（Retina領域内） ---
    if retina_mask_crop is not None:
        mb = compute_mbss_components(cropped, mask01=retina_mask_crop)
    else:
        mb = {"L_multi": None, "HF_ratio": None, "Spec_centroid": None, "Grad_p90": None, "S_mean": None}

    # --- Disc周囲（core/ring） ---
    disc_core_L_multi = None
    disc_ring_L_multi = None
    disc_center_dist_ratio = None
    disc_pos_ok = None
    if disc_mask_crop is not None:
        disc_core_L_multi, disc_ring_L_multi = compute_disc_sharpness_components(cropped, disc_mask_crop)
        est = estimate_disc_center_radius(disc_mask_crop)
        if est is not None:
            dcx, dcy, _ = est
            dist = ( (dcx - center_x) ** 2 + (dcy - center_y) ** 2 ) ** 0.5
            disc_center_dist_ratio = float(dist / max(radius, 1))
            disc_pos_ok = (0.25 <= disc_center_dist_ratio <= 0.75)

    return {
        'image_path': image_path,
        'lens_detected': True,
        'lens_area': lens_area,
        'retina_area': retina_area,
        'retina_ratio': round(float(retina_ratio), 2),
        'disc_detected': bool(disc_detected),
        'macula_detected': bool(macula_detected),
        'mbss_L_multi': mb['L_multi'],
        'mbss_HF_ratio': mb['HF_ratio'],
        'mbss_Spec_centroid': mb['Spec_centroid'],
        'mbss_Grad_p90': mb['Grad_p90'],
        'S_mean': mb.get('S_mean'),
        'disc_core_L_multi': disc_core_L_multi,
        'disc_ring_L_multi': disc_ring_L_multi,
        'disc_center_dist_ratio': disc_center_dist_ratio,
        'disc_pos_ok': disc_pos_ok,
    }

# %% [markdown]
# ---
#
# ## 推論実行（単一ケース）
#
# cell-1 で指定した `image_dir` 内の画像を推論します。
# **1ケースだけ処理したい場合**はこのセルを使用してください。

# %%
# ==================== 推論実行（フォルダ内の全画像） ====================

# 重要: 先に「画像品質特徴量（MBSS）」「process_one_image」セルを実行して、
# compute_mbss_components 等が定義されている必要があります。
required_funcs = [
    'compute_mbss_components',
    'compute_disc_sharpness_components',
    'process_one_image',
]
missing = [n for n in required_funcs if n not in globals()]
if missing:
    raise RuntimeError(
        "必要な関数が未定義です（実行順を確認）: " + ", ".join(missing) +
        "\n→ 上から順にセルを実行（またはKernel再起動→全セル実行）してください。"
    )

print("モデルを読み込んでいます...")
detection_model = RTDETR(rtdetr_model_path)
segmentation_model = YOLO(yolo_seg_model_path)

if torch.cuda.is_available():
    detection_model.to('cuda')
    segmentation_model.to('cuda')
    print("CUDAを使用します")
else:
    print("CPUを使用します")

image_files = sorted([f for f in os.listdir(image_dir) if f.lower().endswith(image_extensions)])
print("画像枚数:", len(image_files))

results = []
for fname in tqdm(image_files, desc="画像を処理中"):
    p = os.path.join(image_dir, fname)
    try:
        r = process_one_image(p, detection_model, segmentation_model)
        if r is None:
            continue
        r['image_name'] = fname
        r['image_id'] = case_id
        results.append(r)
    except Exception as e:
        print(f"エラー: {fname}: {e}")

if not results:
    raise RuntimeError("処理結果が0件です。image_dir/モデル/依存関係を確認してください")

# DataFrame化
_df = pd.DataFrame(results)

# -------------------- スコア算出（ID内でz-score） --------------------

# MBSS stats（None除外）
mb_cols = ['mbss_L_multi', 'mbss_HF_ratio', 'mbss_Spec_centroid', 'mbss_Grad_p90']
stats = {}
for c in mb_cols:
    vals = _df[c].dropna().astype(float)
    key = c.replace('mbss_', '')
    if len(vals) > 0 and float(vals.std()) > 0:
        stats[key] = {"mean": float(vals.mean()), "std": float(vals.std())}
    elif len(vals) > 0:
        stats[key] = {"mean": float(vals.mean()), "std": 1.0}

# MBSS score
mbss_scores = []
for _, row in _df.iterrows():
    comps = {
        "L_multi": row.get('mbss_L_multi'),
        "HF_ratio": row.get('mbss_HF_ratio'),
        "Spec_centroid": row.get('mbss_Spec_centroid'),
        "Grad_p90": row.get('mbss_Grad_p90'),
    }
    if set(stats.keys()) == {"L_multi", "HF_ratio", "Spec_centroid", "Grad_p90"}:
        mbss_scores.append(compute_mbss_score(comps, stats=stats))
    else:
        mbss_scores.append(None)
_df['mbss_score'] = mbss_scores

# Disc core/ring score（z-score）
for col_l, col_s in [('disc_core_L_multi', 'disc_core_score'), ('disc_ring_L_multi', 'disc_ring_score')]:
    vals = _df[col_l].dropna().astype(float)
    if len(vals) > 1 and float(vals.std()) > 0:
        m, s = float(vals.mean()), float(vals.std())
    elif len(vals) > 0:
        m, s = float(vals.mean()), 1.0
    else:
        m, s = 0.0, 1.0

    scores = []
    for v in _df[col_l]:
        if v is None or pd.isna(v):
            scores.append(None)
        else:
            scores.append((float(v) - m) / (s + 1e-8))
    _df[col_s] = scores

# 保存（CSV）
columns_order = [
    'image_id','image_name','image_path','lens_detected','lens_area','retina_area','retina_ratio',
    'disc_detected','macula_detected',
    'mbss_L_multi','mbss_HF_ratio','mbss_Spec_centroid','mbss_Grad_p90','mbss_score',
    'S_mean',
    'disc_core_L_multi','disc_core_score','disc_ring_L_multi','disc_ring_score'
]
columns_order = [c for c in columns_order if c in _df.columns]
_df = _df[columns_order]

_df.to_csv(output_csv_path, index=False, encoding='utf-8-sig')
print("保存しました:", output_csv_path)
print("処理件数:", len(_df))

_df.head()
# Out:
# モデルを読み込んでいます...
# CUDAを使用します
# 画像枚数: 659
# 画像を処理中: 100%|██████████| 659/659 [02:23<00:00,  4.60it/s]
# 保存しました: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1227.csv
# 処理件数: 659
#   image_id         image_name  \
# 0     1227  IMG_1227_0005.jpg
# 1     1227  IMG_1227_0010.jpg
# 2     1227  IMG_1227_0015.jpg
# 3     1227  IMG_1227_0020.jpg
# 4     1227  IMG_1227_0025.jpg
#
#                                           image_path  lens_detected  \
# 0  C:\Users\ykita\ROP_AI_project\ROP_project\best...          False
# 1  C:\Users\ykita\ROP_AI_project\ROP_project\best...           True
# 2  C:\Users\ykita\ROP_AI_project\ROP_project\best...          False
# 3  C:\Users\ykita\ROP_AI_project\ROP_project\best...           True
# 4  C:\Users\ykita\ROP_AI_project\ROP_project\best...           True
#
#    lens_area  retina_area  retina_ratio  disc_detected  macula_detected  \
# 0          0            0           0.0          False            False
# 1     239197            0           0.0          False            False
# 2          0            0           0.0          False            False
# 3     570975            0           0.0          False            False
# 4     431528            0           0.0          False            False
#
#    mbss_L_multi  mbss_HF_ratio  mbss_Spec_centroid  mbss_Grad_p90  mbss_score  \
# 0           NaN            NaN                 NaN            NaN         NaN
# 1           NaN            NaN                 NaN            NaN         NaN
# 2           NaN            NaN                 NaN            NaN         NaN
# 3           NaN            NaN                 NaN            NaN         NaN
# 4           NaN            NaN                 NaN            NaN         NaN
#
#    S_mean  disc_core_L_multi  disc_core_score  disc_ring_L_multi  \
# 0     NaN                NaN              NaN                NaN
# 1     NaN                NaN              NaN                NaN
# 2     NaN                NaN              NaN                NaN
# 3     NaN                NaN              NaN                NaN
# 4     NaN                NaN              NaN                NaN
#
#    disc_ring_score
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# ---
#
# ## バッチ推論（複数ケース）
#
# `bestimage_validation/*/images/` 内の全ケースを一括で推論します。
#
# ### 特徴
# - 既に `validation_results_*.csv` が存在するケースは**スキップ**（上書き防止）
# - 全て再推論したい場合は `skip_existing = False` に変更
# - モデルは最初に1回だけ読み込み（効率的）
#
# ### 実行順序
# 1. **下のセル（ケース検索）**: 推論対象のケースを確認
# 2. **その次のセル（推論実行）**: 実際に推論を実行

# %%
# ==================== バッチ推論（複数ケース） ====================
# 説明: bestimage_validation/*/images/ 内の全ケースを推論
# 既に validation_results_*.csv が存在するケースはスキップ（上書き防止）

import glob
from pathlib import Path

# -------------------- パラメータ --------------------
# 推論対象のルートフォルダ
batch_root = r"C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation"

# 既存CSVをスキップするか（Falseにすると全て再推論）
skip_existing = False

# モデルパス（cell-1と同じ）
rtdetr_model_path = r"C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\models\\rtdetr-l-1697_1703.pt"
yolo_seg_model_path = r"C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\models\\yolo11n-seg_19movies.pt"

# 出力先
validation_results_dir = Path(batch_root) / "validation_results"
validation_results_dir.mkdir(parents=True, exist_ok=True)

# 画像拡張子
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')

# YOLO入力幅
YOLO_INPUT_WIDTH = 640

# -------------------- ケースフォルダの検索 --------------------
# パターン: bestimage_validation/*/images/
case_folders = sorted(glob.glob(os.path.join(batch_root, "*", "images")))
case_folders = [f for f in case_folders if os.path.isdir(f)]

print(f"見つかったケースフォルダ数: {len(case_folders)}")

# 既存CSVの確認
existing_csvs = set()
if skip_existing:
    for csv_file in glob.glob(str(validation_results_dir / "validation_results_*.csv")):
        # ファイル名から case_id を抽出
        fname = os.path.basename(csv_file)
        case_id_from_csv = fname.replace("validation_results_", "").replace(".csv", "")
        existing_csvs.add(case_id_from_csv)
    print(f"既存CSV数: {len(existing_csvs)}")

# 推論対象のケースをフィルタリング
cases_to_process = []
for folder in case_folders:
    case_id = Path(folder).parent.name
    if skip_existing and case_id in existing_csvs:
        continue
    cases_to_process.append((case_id, folder))

print(f"推論対象ケース数: {len(cases_to_process)}")

if len(cases_to_process) == 0:
    print("\n推論対象のケースがありません。")
    print("全て再推論する場合は skip_existing = False に設定してください。")
else:
    for case_id, folder in cases_to_process:
        print(f"  - {case_id}: {folder}")
# Out:
# 見つかったケースフォルダ数: 22
# 推論対象ケース数: 22
#   - 1227: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1227\images
#   - 1363: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1363\images
#   - 1376: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1376\images
#   - 1601: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1601\images
#   - 1632: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1632\images
#   - 1703: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1703\images
#   - 1732: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1732\images
#   - 1891: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1891\images
#   - 1966: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\1966\images
#   - 2024: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2024\images
#   - 2026: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2026\images
#   - 2028: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2028\images
#   - 2116: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2116\images
#   - 2168: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2168\images
#   - 2232: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2232\images
#   - 2289: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2289\images
#   - 2290: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2290\images
#   - 2356: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2356\images
#   - 2358: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2358\images
#   - 2376: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2376\images
#   - 2403: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2403\images
#   - 2431: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\2431\images

# %%
# ==================== バッチ推論実行 ====================
# 上のセルで cases_to_process が定義されている必要があります

if len(cases_to_process) == 0:
    print("推論対象のケースがありません。上のセルを確認してください。")
else:
    # モデル読み込み（1回のみ）
    print("モデルを読み込んでいます...")
    detection_model = RTDETR(rtdetr_model_path)
    segmentation_model = YOLO(yolo_seg_model_path)

    if torch.cuda.is_available():
        detection_model.to('cuda')
        segmentation_model.to('cuda')
        print("CUDAを使用します")
    else:
        print("CPUを使用します")

    # 全ケースの処理
    total_cases = len(cases_to_process)
    
    for case_idx, (case_id, image_dir) in enumerate(cases_to_process, 1):
        print(f"\n{'='*60}")
        print(f"[{case_idx}/{total_cases}] ケース: {case_id}")
        print(f"{'='*60}")
        
        # 画像ファイル取得
        image_files = sorted([f for f in os.listdir(image_dir) if f.lower().endswith(image_extensions)])
        print(f"画像枚数: {len(image_files)}")
        
        if len(image_files) == 0:
            print("  → スキップ（画像なし）")
            continue
        
        # 推論実行
        results = []
        for fname in tqdm(image_files, desc=f"  {case_id} 処理中"):
            p = os.path.join(image_dir, fname)
            try:
                r = process_one_image(p, detection_model, segmentation_model)
                if r is None:
                    continue
                r['image_name'] = fname
                r['image_id'] = case_id
                results.append(r)
            except Exception as e:
                print(f"  エラー: {fname}: {e}")
        
        if not results:
            print(f"  → スキップ（処理結果なし）")
            continue
        
        # DataFrame化
        df = pd.DataFrame(results)
        
        # -------------------- スコア算出（ケース内でz-score） --------------------
        mb_cols = ['mbss_L_multi', 'mbss_HF_ratio', 'mbss_Spec_centroid', 'mbss_Grad_p90']
        stats = {}
        for c in mb_cols:
            vals = df[c].dropna().astype(float)
            key = c.replace('mbss_', '')
            if len(vals) > 0 and float(vals.std()) > 0:
                stats[key] = {"mean": float(vals.mean()), "std": float(vals.std())}
            elif len(vals) > 0:
                stats[key] = {"mean": float(vals.mean()), "std": 1.0}
        
        # MBSS score
        mbss_scores = []
        for _, row in df.iterrows():
            comps = {
                "L_multi": row.get('mbss_L_multi'),
                "HF_ratio": row.get('mbss_HF_ratio'),
                "Spec_centroid": row.get('mbss_Spec_centroid'),
                "Grad_p90": row.get('mbss_Grad_p90'),
            }
            if set(stats.keys()) == {"L_multi", "HF_ratio", "Spec_centroid", "Grad_p90"}:
                mbss_scores.append(compute_mbss_score(comps, stats=stats))
            else:
                mbss_scores.append(None)
        df['mbss_score'] = mbss_scores
        
        # Disc core/ring score（z-score）
        for col_l, col_s in [('disc_core_L_multi', 'disc_core_score'), ('disc_ring_L_multi', 'disc_ring_score')]:
            vals = df[col_l].dropna().astype(float)
            if len(vals) > 1 and float(vals.std()) > 0:
                m, s = float(vals.mean()), float(vals.std())
            elif len(vals) > 0:
                m, s = float(vals.mean()), 1.0
            else:
                m, s = 0.0, 1.0
            
            scores = []
            for v in df[col_l]:
                if v is None or pd.isna(v):
                    scores.append(None)
                else:
                    scores.append((float(v) - m) / (s + 1e-8))
            df[col_s] = scores
        
        # カラム整理
        columns_order = [
            'image_id','image_name','image_path','lens_detected','lens_area','retina_area','retina_ratio',
            'disc_detected','macula_detected',
            'mbss_L_multi','mbss_HF_ratio','mbss_Spec_centroid','mbss_Grad_p90','mbss_score',
            'S_mean',
            'disc_core_L_multi','disc_core_score','disc_ring_L_multi','disc_ring_score',
            'disc_center_dist_ratio', 'disc_pos_ok'
        ]
        columns_order = [c for c in columns_order if c in df.columns]
        df = df[columns_order]
        
        # CSV保存
        output_csv_path = validation_results_dir / f"validation_results_{case_id}.csv"
        df.to_csv(output_csv_path, index=False, encoding='utf-8-sig')
        print(f"  保存: {output_csv_path}")
        print(f"  処理件数: {len(df)}")
    
    print(f"\n{'='*60}")
    print(f"バッチ推論完了: {total_cases}ケース")
    print(f"{'='*60}")
# Out:
# モデルを読み込んでいます...
# CUDAを使用します
#
# ============================================================
# [1/22] ケース: 1227
# ============================================================
# 画像枚数: 659
#   1227 処理中: 100%|██████████| 659/659 [02:21<00:00,  4.66it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1227.csv
#   処理件数: 659
#
# ============================================================
# [2/22] ケース: 1363
# ============================================================
# 画像枚数: 385
#   1363 処理中: 100%|██████████| 385/385 [01:34<00:00,  4.09it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1363.csv
#   処理件数: 385
#
# ============================================================
# [3/22] ケース: 1376
# ============================================================
# 画像枚数: 758
#   1376 処理中: 100%|██████████| 758/758 [02:36<00:00,  4.86it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1376.csv
#   処理件数: 758
#
# ============================================================
# [4/22] ケース: 1601
# ============================================================
# 画像枚数: 358
#   1601 処理中: 100%|██████████| 358/358 [01:29<00:00,  4.02it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1601.csv
#   処理件数: 358
#
# ============================================================
# [5/22] ケース: 1632
# ============================================================
# 画像枚数: 676
#   1632 処理中: 100%|██████████| 676/676 [01:58<00:00,  5.71it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1632.csv
#   処理件数: 676
#
# ============================================================
# [6/22] ケース: 1703
# ============================================================
# 画像枚数: 177
#   1703 処理中: 100%|██████████| 177/177 [00:37<00:00,  4.75it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1703.csv
#   処理件数: 177
#
# ============================================================
# [7/22] ケース: 1732
# ============================================================
# 画像枚数: 121
#   1732 処理中: 100%|██████████| 121/121 [00:27<00:00,  4.32it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1732.csv
#   処理件数: 121
#
# ============================================================
# [8/22] ケース: 1891
# ============================================================
# 画像枚数: 103
#   1891 処理中: 100%|██████████| 103/103 [00:30<00:00,  3.33it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1891.csv
#   処理件数: 103
#
# ============================================================
# [9/22] ケース: 1966
# ============================================================
# 画像枚数: 126
#   1966 処理中: 100%|██████████| 126/126 [00:30<00:00,  4.11it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_1966.csv
#   処理件数: 126
#
# ============================================================
# [10/22] ケース: 2024
# ============================================================
# 画像枚数: 347
#   2024 処理中: 100%|██████████| 347/347 [01:19<00:00,  4.36it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2024.csv
#   処理件数: 347
#
# ============================================================
# [11/22] ケース: 2026
# ============================================================
# 画像枚数: 98
#   2026 処理中: 100%|██████████| 98/98 [00:19<00:00,  4.92it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2026.csv
#   処理件数: 98
#
# ============================================================
# [12/22] ケース: 2028
# ============================================================
# 画像枚数: 146
#   2028 処理中: 100%|██████████| 146/146 [00:29<00:00,  4.98it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2028.csv
#   処理件数: 146
#
# ============================================================
# [13/22] ケース: 2116
# ============================================================
# 画像枚数: 123
#   2116 処理中: 100%|██████████| 123/123 [00:31<00:00,  3.89it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2116.csv
#   処理件数: 123
#
# ============================================================
# [14/22] ケース: 2168
# ============================================================
# 画像枚数: 608
#   2168 処理中: 100%|██████████| 608/608 [01:51<00:00,  5.43it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2168.csv
#   処理件数: 608
#
# ============================================================
# [15/22] ケース: 2232
# ============================================================
# 画像枚数: 110
#   2232 処理中: 100%|██████████| 110/110 [00:27<00:00,  4.01it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2232.csv
#   処理件数: 110
#
# ============================================================
# [16/22] ケース: 2289
# ============================================================
# 画像枚数: 363
#   2289 処理中: 100%|██████████| 363/363 [00:55<00:00,  6.50it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2289.csv
#   処理件数: 363
#
# ============================================================
# [17/22] ケース: 2290
# ============================================================
# 画像枚数: 231
#   2290 処理中: 100%|██████████| 231/231 [00:50<00:00,  4.62it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2290.csv
#   処理件数: 231
#
# ============================================================
# [18/22] ケース: 2356
# ============================================================
# 画像枚数: 153
#   2356 処理中: 100%|██████████| 153/153 [00:44<00:00,  3.41it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2356.csv
#   処理件数: 153
#
# ============================================================
# [19/22] ケース: 2358
# ============================================================
# 画像枚数: 228
#   2358 処理中: 100%|██████████| 228/228 [00:37<00:00,  6.03it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2358.csv
#   処理件数: 228
#
# ============================================================
# [20/22] ケース: 2376
# ============================================================
# 画像枚数: 301
#   2376 処理中: 100%|██████████| 301/301 [00:59<00:00,  5.05it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2376.csv
#   処理件数: 301
#
# ============================================================
# [21/22] ケース: 2403
# ============================================================
# 画像枚数: 271
#   2403 処理中: 100%|██████████| 271/271 [00:51<00:00,  5.28it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2403.csv
#   処理件数: 271
#
# ============================================================
# [22/22] ケース: 2431
# ============================================================
# 画像枚数: 347
#   2431 処理中: 100%|██████████| 347/347 [01:03<00:00,  5.47it/s]
#   保存: C:\Users\ykita\ROP_AI_project\ROP_project\bestimage_validation\validation_results\validation_results_2431.csv
#   処理件数: 347
#
# ============================================================
# バッチ推論完了: 22ケース
# ============================================================

# %% [markdown]
# ---
#
# ## Best画像選定（単一ケース）
#
# 上の推論結果（`_df`）からBest画像を選定します。
# **単一ケースの場合**はこのセルを使用してください。

# %%
# ==================== Best画像選定（新アプローチ） ====================
# 方針:
# 1. disc_pos_ok=True の画像を優先的に抽出
# 2. retina_area でベースランキング
# 3. 品質指標（disc_ring_score, S_mean, mbss_score）でボーナス
# 4. 画像が足りなければ disc_pos_ok=False から補完

# -------------------- ここを変更 --------------------
case_id = "1601"  # 患者番号を指定
# ---------------------------------------------------

# -------------------- パラメータ --------------------
TOP_K_TOTAL = 30    # 最終出力の目標数

# ボーナス重み（ランク計算用）
WEIGHT_RETINA = 1.5      # retina_area の重み（ベース）
WEIGHT_MBSS = 1.0        # mbss_score の重み
WEIGHT_DISC_RING = 0.5   # disc_ring_score の重み
WEIGHT_S_MEAN = 0.5      # S_mean の重み

# -------------------- CSVから読み込み or 既存_dfを使用 --------------------
output_root = Path(r"C:\\Users\\ykita\\ROP_AI_project\\ROP_project\\bestimage_validation")
validation_results_dir = output_root / "validation_results"
output_best_xlsx_path = output_root / f"best_images_{case_id}.xlsx"

csv_path = validation_results_dir / f"validation_results_{case_id}.csv"

if csv_path.exists():
    print(f"CSVから読み込み: {csv_path}")
    _df = pd.read_csv(csv_path)
elif '_df' in dir() and len(_df) > 0:
    print(f"メモリ上の_dfを使用（{len(_df)}件）")
else:
    raise RuntimeError(f"CSVが見つかりません: {csv_path}\n先に推論セルを実行してください。")

print(f"case_id: {case_id}")
print(f"出力先: {output_best_xlsx_path}")

# -------------------- 有効データ抽出 --------------------
valid = _df[(_df['lens_detected'] == True) & (_df['retina_ratio'] > 0)].copy()

if len(valid) == 0:
    raise RuntimeError("lens_detected=True かつ retina_ratio>0 のデータがありません")

print(f"\n有効データ: {len(valid)}件")

# -------------------- カラム補完 --------------------
if 'mbss_score' not in valid.columns:
    valid['mbss_score'] = np.nan
if 'disc_core_score' not in valid.columns:
    valid['disc_core_score'] = np.nan
if 'disc_ring_score' not in valid.columns:
    valid['disc_ring_score'] = np.nan
if 'S_mean' not in valid.columns:
    valid['S_mean'] = np.nan
if 'disc_pos_ok' not in valid.columns:
    valid['disc_pos_ok'] = False
if 'disc_detected' not in valid.columns:
    valid['disc_detected'] = False
if 'retina_area' not in valid.columns:
    valid['retina_area'] = valid['retina_ratio']  # fallback

# -------------------- ランキング計算 --------------------
# 各指標のランク（小さいほど良い）
valid['retina_area_rank'] = valid['retina_area'].rank(ascending=False, method='min', na_option='bottom')
valid['mbss_rank'] = valid['mbss_score'].rank(ascending=False, method='min', na_option='bottom')
valid['disc_ring_rank'] = valid['disc_ring_score'].rank(ascending=False, method='min', na_option='bottom')
valid['s_mean_rank'] = valid['S_mean'].rank(ascending=False, method='min', na_option='bottom')

# 総合ランクスコア（小さいほど上位）
valid['rank_sum'] = (
    WEIGHT_RETINA * valid['retina_area_rank'] +
    WEIGHT_MBSS * valid['mbss_rank'] +
    WEIGHT_DISC_RING * valid['disc_ring_rank'] +
    WEIGHT_S_MEAN * valid['s_mean_rank']
)

# -------------------- Stage 1: disc_pos_ok=True の画像 --------------------
print("\n===== Stage 1: disc_pos_ok=True の画像 =====")

disc_pos_true = valid[valid['disc_pos_ok'] == True].copy()
print(f"disc_pos_ok=True: {len(disc_pos_true)}件")

# rank_sum でソート（小さい順＝上位）
if len(disc_pos_true) > 0:
    disc_pos_true = disc_pos_true.sort_values(
        by=['rank_sum', 'retina_area'],
        ascending=[True, False]
    )
    stage1_selected = disc_pos_true.head(TOP_K_TOTAL).copy()
    stage1_selected['selection_stage'] = 'disc_pos_ok=True'
else:
    stage1_selected = pd.DataFrame()

print(f"Stage 1 選定: {len(stage1_selected)}件")

# -------------------- Stage 2: disc_pos_ok=False の画像（補完） --------------------
print("\n===== Stage 2: disc_pos_ok=False の画像（補完） =====")

n_remaining = TOP_K_TOTAL - len(stage1_selected)

if n_remaining > 0:
    # Stage 1で選ばれなかった画像 + disc_pos_ok=Falseの画像
    remaining = valid[~valid.index.isin(stage1_selected.index)].copy()
    
    if len(remaining) > 0:
        remaining = remaining.sort_values(
            by=['rank_sum', 'retina_area'],
            ascending=[True, False]
        )
        stage2_selected = remaining.head(n_remaining).copy()
        stage2_selected['selection_stage'] = 'disc_pos_ok=False'
        print(f"Stage 2 選定: {len(stage2_selected)}件")
    else:
        stage2_selected = pd.DataFrame()
        print("Stage 2 選定: 0件（残り画像なし）")
else:
    stage2_selected = pd.DataFrame()
    print("Stage 2 選定: 0件（Stage 1で十分）")

# -------------------- 最終結果の結合 --------------------
final_top = pd.concat([stage1_selected, stage2_selected], ignore_index=False)
final_top = final_top.reset_index(drop=True)
final_top['rank'] = range(1, len(final_top) + 1)

print(f"\n===== 最終結果: {len(final_top)}件 =====")
print(f"  Stage 1 (disc_pos_ok=True): {len(stage1_selected)}件")
print(f"  Stage 2 (disc_pos_ok=False): {len(stage2_selected)}件")

# -------------------- 表示 --------------------
print("\n=== Best Top10 ===")
for i, row in final_top.head(10).iterrows():
    print(f"  {row['rank']:2d}. {row['image_name']} (retina={row['retina_area']:.0f}, disc_pos={row['disc_pos_ok']}, rank_sum={row['rank_sum']:.1f})")

print("\n=== Best 11-30 ===")
if len(final_top) > 10:
    for i, row in final_top.iloc[10:30].iterrows():
        print(f"  {row['rank']:2d}. {row['image_name']} (retina={row['retina_area']:.0f}, disc_pos={row['disc_pos_ok']})")
else:
    print("(なし)")

# -------------------- Excel保存 --------------------
out_cols = [
    'rank', 'image_id', 'image_name', 'image_path', 'selection_stage',
    'disc_pos_ok', 'disc_detected', 'retina_area', 'retina_ratio', 'S_mean', 
    'mbss_score', 'disc_core_score', 'disc_ring_score',
    'rank_sum', 'retina_area_rank', 'mbss_rank', 'disc_ring_rank', 's_mean_rank'
]
out_cols = [c for c in out_cols if c in final_top.columns]

out_df = final_top[out_cols].copy()
try:
    out_df.to_excel(output_best_xlsx_path, index=False)
    print(f"\n保存しました: {output_best_xlsx_path}")
except Exception as e:
    print(f"\nExcel出力に失敗しました: {e}")
    alt_csv = output_best_xlsx_path.with_suffix('.csv')
    out_df.to_csv(alt_csv, index=False, encoding='utf-8-sig')
    print(f"代替でCSV保存しました: {alt_csv}")

out_df.head(15)

# -------------------- Best5画像表示 --------------------
print("\n===== Best5 画像表示 =====")
try:
    from PIL import Image
    import matplotlib.pyplot as plt

    paths = final_top.head(5)['image_path'].tolist() if 'image_path' in final_top.columns else []
    if len(paths) == 0:
        print("Best5画像が見つかりません")
    else:
        for i, p in enumerate(paths, 1):
            row = final_top.iloc[i-1]
            img = Image.open(p)
            plt.figure(figsize=(6, 6))
            plt.imshow(img)
            title = f"#{i}: {os.path.basename(p)}\nretina_area={row['retina_area']:.0f}, disc_pos_ok={row.get('disc_pos_ok', None)}"
            plt.title(title)
            plt.axis('off')
            plt.tight_layout()
            plt.show()
except Exception as e:
    print("Best5画像表示エラー:", e)

# %% [markdown]
# ---
#
# ## Best画像選定（バッチ：複数ケース）
#
# `validation_results/` フォルダ内の全CSVファイルを読み込み、
# 各ケースのBest画像（Top30）を1つのExcelファイルにまとめて出力します。
#
# ### 出力先
# `D:\ダウンロード\bestimage_list.xlsx`（変更可）

# %%
# ==================== Best画像選定（バッチ：新アプローチ） ====================
# 方針:
# 1. disc_pos_ok=True の画像を優先的に抽出
# 2. retina_area でベースランキング
# 3. 品質指標（disc_ring_score, S_mean, mbss_score）でボーナス
# 4. 画像が足りなければ disc_pos_ok=False から補完

import glob
from datetime import datetime

# -------------------- パラメータ --------------------
TOP_K_TOTAL = 30    # 最終出力の目標数

# ボーナス重み（ランク計算用）
WEIGHT_RETINA = 1.5      # retina_area の重み（ベース）
WEIGHT_MBSS = 1.0        # mbss_score の重み
WEIGHT_DISC_RING = 0.5   # disc_ring_score の重み
WEIGHT_S_MEAN = 0.5      # S_mean の重み

# 出力先
output_xlsx_path = r"D:\ダウンロード\bestimage_list.xlsx"

# validation_resultsフォルダ内のCSVファイルを取得
csv_files = sorted(glob.glob(str(validation_results_dir / "validation_results_*.csv")))
csv_files = [f for f in csv_files if os.path.basename(f) != "validation_results_all.csv"]

print(f"見つかったCSVファイル数: {len(csv_files)}")

# 重複チェック
csv_by_id = {}
for csv_file in csv_files:
    try:
        df_head = pd.read_csv(csv_file, nrows=1)
        if 'image_id' in df_head.columns and len(df_head) > 0:
            image_id = str(df_head.iloc[0]['image_id'])
        else:
            image_id = Path(csv_file).stem.replace('validation_results_', '')
    except Exception:
        image_id = Path(csv_file).stem.replace('validation_results_', '')
    
    mtime = os.path.getmtime(csv_file)
    if image_id in csv_by_id:
        prev_file, prev_mtime = csv_by_id[image_id]
        if mtime > prev_mtime:
            print(f"[WARN] 重複CSV検出: image_id={image_id}. 新しいファイルを使用: {Path(csv_file).name}")
            csv_by_id[image_id] = (csv_file, mtime)
    else:
        csv_by_id[image_id] = (csv_file, mtime)

csv_items = sorted([(image_id, f_m[0]) for image_id, f_m in csv_by_id.items()], key=lambda x: x[0])
print(f"ユニークなimage_id数: {len(csv_items)}")

all_best_images = []

for image_id, csv_file in csv_items:
    try:
        df = pd.read_csv(csv_file)
        if len(df) == 0:
            continue
        
        print(f"\n処理中: {image_id}...")
        
        if 'lens_detected' not in df.columns or 'retina_ratio' not in df.columns:
            print(f"  スキップ: 必要なカラムがありません")
            continue
        
        df_valid = df[(df['lens_detected'] == True) & (df['retina_ratio'] > 0)].copy()
        
        if len(df_valid) == 0:
            print(f"  スキップ: 有効なデータがありません")
            continue
        
        # -------------------- カラム補完 --------------------
        if 'mbss_score' not in df_valid.columns:
            df_valid['mbss_score'] = np.nan
        if 'disc_core_score' not in df_valid.columns:
            df_valid['disc_core_score'] = np.nan
        if 'disc_ring_score' not in df_valid.columns:
            df_valid['disc_ring_score'] = np.nan
        if 'S_mean' not in df_valid.columns:
            df_valid['S_mean'] = np.nan
        if 'disc_pos_ok' not in df_valid.columns:
            df_valid['disc_pos_ok'] = False
        if 'disc_detected' not in df_valid.columns:
            df_valid['disc_detected'] = False
        if 'retina_area' not in df_valid.columns:
            df_valid['retina_area'] = df_valid['retina_ratio']  # fallback
        
        # -------------------- ランキング計算 --------------------
        df_valid['retina_area_rank'] = df_valid['retina_area'].rank(ascending=False, method='min', na_option='bottom')
        df_valid['mbss_rank'] = df_valid['mbss_score'].rank(ascending=False, method='min', na_option='bottom')
        df_valid['disc_ring_rank'] = df_valid['disc_ring_score'].rank(ascending=False, method='min', na_option='bottom')
        df_valid['s_mean_rank'] = df_valid['S_mean'].rank(ascending=False, method='min', na_option='bottom')
        
        # 総合ランクスコア（小さいほど上位）
        df_valid['rank_sum'] = (
            WEIGHT_RETINA * df_valid['retina_area_rank'] +
            WEIGHT_MBSS * df_valid['mbss_rank'] +
            WEIGHT_DISC_RING * df_valid['disc_ring_rank'] +
            WEIGHT_S_MEAN * df_valid['s_mean_rank']
        )
        
        # -------------------- Stage 1: disc_pos_ok=True の画像 --------------------
        disc_pos_true = df_valid[df_valid['disc_pos_ok'] == True].copy()
        
        if len(disc_pos_true) > 0:
            disc_pos_true = disc_pos_true.sort_values(
                by=['rank_sum', 'retina_area'],
                ascending=[True, False]
            )
            stage1_selected = disc_pos_true.head(TOP_K_TOTAL).copy()
            stage1_selected['selection_stage'] = 'disc_pos_ok=True'
        else:
            stage1_selected = pd.DataFrame()
        
        # -------------------- Stage 2: disc_pos_ok=False の画像（補完） --------------------
        n_remaining = TOP_K_TOTAL - len(stage1_selected)
        
        if n_remaining > 0:
            remaining = df_valid[~df_valid.index.isin(stage1_selected.index)].copy()
            
            if len(remaining) > 0:
                remaining = remaining.sort_values(
                    by=['rank_sum', 'retina_area'],
                    ascending=[True, False]
                )
                stage2_selected = remaining.head(n_remaining).copy()
                stage2_selected['selection_stage'] = 'disc_pos_ok=False'
            else:
                stage2_selected = pd.DataFrame()
        else:
            stage2_selected = pd.DataFrame()
        
        # -------------------- 結合 --------------------
        final_top = pd.concat([stage1_selected, stage2_selected], ignore_index=False)
        
        # 結果を追加
        for rank, (idx, row) in enumerate(final_top.iterrows(), 1):
            res = {
                'image_id': image_id,
                'rank': rank,
                'image_name': row['image_name'],
                'selection_stage': row.get('selection_stage', ''),
                'disc_pos_ok': row.get('disc_pos_ok'),
                'disc_detected': row.get('disc_detected'),
                'retina_area': row.get('retina_area'),
                'retina_ratio': row.get('retina_ratio'),
                'S_mean': row.get('S_mean'),
                'disc_center_dist_ratio': row.get('disc_center_dist_ratio'),
                'mbss_score': row.get('mbss_score'),
                'disc_core_score': row.get('disc_core_score'),
                'disc_ring_score': row.get('disc_ring_score'),
                'rank_sum': row.get('rank_sum'),
                'retina_area_rank': row.get('retina_area_rank'),
                'mbss_rank': row.get('mbss_rank'),
            }
            all_best_images.append(res)
        
        print(f"  Stage1(disc_pos=True): {len(stage1_selected)}件, Stage2(disc_pos=False): {len(stage2_selected)}件, 合計: {len(final_top)}件")
        
    except Exception as e:
        print(f"  エラー: {e}")
        import traceback
        traceback.print_exc()

# Excelに保存
if all_best_images:
    df_out = pd.DataFrame(all_best_images)
    
    output_dir = Path(output_xlsx_path).parent
    output_dir.mkdir(parents=True, exist_ok=True)
    
    try:
        df_out.to_excel(output_xlsx_path, index=False)
        print(f"\n保存しました: {output_xlsx_path}")
        print(f"総行数: {len(df_out)}")
        
        # 統計情報
        stage1_count = len(df_out[df_out['selection_stage'] == 'disc_pos_ok=True'])
        stage2_count = len(df_out[df_out['selection_stage'] == 'disc_pos_ok=False'])
        print(f"  Stage1 (disc_pos_ok=True): {stage1_count}件")
        print(f"  Stage2 (disc_pos_ok=False): {stage2_count}件")
        
    except PermissionError as e:
        ts = datetime.now().strftime("%Y%m%d_%H%M%S")
        root, ext = os.path.splitext(output_xlsx_path)
        alt_path = f"{root}_{ts}{ext}"
        df_out.to_excel(alt_path, index=False)
        print(f"\n[WARN] 出力先ファイルが使用中のため上書きできませんでした: {output_xlsx_path}")
        print(f"       代替ファイルに保存しました: {alt_path}")
        print(f"       総行数: {len(df_out)}")
else:
    print("\n結果が見つかりませんでした。")
# Out:
# 見つかったCSVファイル数: 22
# ユニークなimage_id数: 22
#
# 処理中: 1227...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 1363...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 1376...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 1601...
#   Stage1(disc_pos=True): 20件, Stage2(disc_pos=False): 10件, 合計: 30件
#
# 処理中: 1632...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 1703...
#   Stage1(disc_pos=True): 24件, Stage2(disc_pos=False): 6件, 合計: 30件
#
# 処理中: 1732...
#   Stage1(disc_pos=True): 21件, Stage2(disc_pos=False): 9件, 合計: 30件
#
# 処理中: 1891...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 1966...
#   Stage1(disc_pos=True): 22件, Stage2(disc_pos=False): 8件, 合計: 30件
#
# 処理中: 2024...
#   Stage1(disc_pos=True): 22件, Stage2(disc_pos=False): 8件, 合計: 30件
#
# 処理中: 2026...
#   Stage1(disc_pos=True): 25件, Stage2(disc_pos=False): 5件, 合計: 30件
#
# 処理中: 2028...
#   Stage1(disc_pos=True): 17件, Stage2(disc_pos=False): 13件, 合計: 30件
#
# 処理中: 2116...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 2168...
#   Stage1(disc_pos=True): 17件, Stage2(disc_pos=False): 13件, 合計: 30件
#
# 処理中: 2232...
#   Stage1(disc_pos=True): 14件, Stage2(disc_pos=False): 16件, 合計: 30件
#
# 処理中: 2289...
#   Stage1(disc_pos=True): 14件, Stage2(disc_pos=False): 16件, 合計: 30件
#
# 処理中: 2290...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 2356...
#   Stage1(disc_pos=True): 24件, Stage2(disc_pos=False): 6件, 合計: 30件
#
# 処理中: 2358...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 2376...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 2403...
#   Stage1(disc_pos=True): 30件, Stage2(disc_pos=False): 0件, 合計: 30件
#
# 処理中: 2431...
#   Stage1(disc_pos=True): 24件, Stage2(disc_pos=False): 6件, 合計: 30件
#
# 保存しました: D:\ダウンロード\bestimage_list.xlsx
# 総行数: 660
#   Stage1 (disc_pos_ok=True): 544件
#   Stage2 (disc_pos_ok=False): 116件
